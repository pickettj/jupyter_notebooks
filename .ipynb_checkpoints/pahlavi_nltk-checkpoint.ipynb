# %% [markdown]
# ### Libraries

# %%
import nltk, os
import pandas as pd

# %% [markdown]
# ### Importing Pahlavi Corpus

# %%
os.chdir('/Users/Enkidu/Documents/digital_humanities/pahlavi_corpus_digital/')
f = open('pahlavi_corpus_comp_ling.txt')
pahlavi_text = f.read()
f.close()

# %% [markdown]
# ### Tokenizing

# %%
pah_toks = nltk.word_tokenize(pahlavi_text)

len(pah_toks)
# Out:
# 1036918

# %%
'handarz' in pah_toks
# Out:
# True

# %% [markdown]
# ### Cleaning the Tokens

# %% [markdown]
# *next steps*: still messing up boolean logic in latter part of the string comprehension

# %%
pah_toks_clean = [x for x in pah_toks if x.isalpha() or '-' in x]

# %%
pah_toks_clean = [x for x in pah_toks if x.lower() not in ('colophon', 'n', 'not', 'texts', '...')]

# %%
pah_toks_clean = [x for x in pah_toks_clean if len(x) > 2]
print ('Number of clean tokens: ', str(len(pah_toks_clean)))
print ('Tokens reduced by', str(int(len(pah_toks_clean)/len(pah_toks)*100)), 'percent in cleaning process.')
# Out:
# Number of clean tokens:  487022
# Tokens reduced by 46 percent in cleaning process.

# %%
'not' in pah_toks_clean
# don't understand why 'not' is still in the list
# Out:
# False

# %%
pah_long_toks = [x for x in pah_toks_clean if '-' in x and len(x)>12]
long_freq = nltk.FreqDist(pah_long_toks)
long_freq.most_common(10)
# Out:
# [('bowandag-menišnīh', 97),
#  ('meh-dādestānīh', 50),
#  ('dūdag-sālārīh', 39),
#  ('fraškerd-kerdārīh', 38),
#  ('ham-dādestānīh', 36),
#  ('bē-widerišnīh', 35),
#  ('hamē-rawišnīh', 27),
#  ('harwisp-āgāhīh', 26),
#  ('rāst-gōwišnīh', 24),
#  ('azabar-nibišt', 23)]

# %% [markdown]
# ### Word Frequency

# %% [markdown]
# *next steps*: need to figure out how to better take advantage of the iterator (same for below)

# %%
pah_freq = nltk.FreqDist(pah_toks_clean)
pah_freq.most_common(20)
# Out:
# [('pad', 19534),
#  ('andar', 5979),
#  ('abar', 4963),
#  ('bawēd', 4604),
#  ('čiyōn', 3774),
#  ('u-š', 3623),
#  ('rāy', 2915),
#  ('ast', 2660),
#  ('harw', 2478),
#  ('estēd', 2428),
#  ('būd', 2389),
#  ('xwēš', 2258),
#  ('tan', 2194),
#  ('guft', 2156),
#  ('Ohrmazd', 2066),
#  ('kerd', 2014),
#  ('dād', 1937),
#  ('dēn', 1898),
#  ('ayāb', 1752),
#  ('abāg', 1710)]

# %%
help(pah_freq)
# Out:
# Help on FreqDist in module nltk.probability object:
#
# class FreqDist(collections.Counter)
#  |  A frequency distribution for the outcomes of an experiment.  A
#  |  frequency distribution records the number of times each outcome of
#  |  an experiment has occurred.  For example, a frequency distribution
#  |  could be used to record the frequency of each word type in a
#  |  document.  Formally, a frequency distribution can be defined as a
#  |  function mapping from each sample to the number of times that
#  |  sample occurred as an outcome.
#  |
#  |  Frequency distributions are generally constructed by running a
#  |  number of experiments, and incrementing the count for a sample
#  |  every time it is an outcome of an experiment.  For example, the
#  |  following code will produce a frequency distribution that encodes
#  |  how often each word occurs in a text:
#  |
#  |      >>> from nltk.tokenize import word_tokenize
#  |      >>> from nltk.probability import FreqDist
#  |      >>> sent = 'This is an example sentence'
#  |      >>> fdist = FreqDist()
#  |      >>> for word in word_tokenize(sent):
#  |      ...    fdist[word.lower()] += 1
#  |
#  |  An equivalent way to do this is with the initializer:
#  |
#  |      >>> fdist = FreqDist(word.lower() for word in word_tokenize(sent))
#  |
#  |  Method resolution order:
#  |      FreqDist
#  |      collections.Counter
#  |      builtins.dict
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  B(self)
#  |      Return the total number of sample values (or "bins") that
#  |      have counts greater than zero.  For the total
#  |      number of sample outcomes recorded, use ``FreqDist.N()``.
#  |      (FreqDist.B() is the same as len(FreqDist).)
#  |
#  |      :rtype: int
#  |
#  |  N(self)
#  |      Return the total number of sample outcomes that have been
#  |      recorded by this FreqDist.  For the number of unique
#  |      sample values (or bins) with counts greater than zero, use
#  |      ``FreqDist.B()``.
#  |
#  |      :rtype: int
#  |
#  |  Nr(self, r, bins=None)
#  |
#  |  __add__(self, other)
#  |      Add counts from two counters.
#  |
#  |      >>> FreqDist('abbb') + FreqDist('bcc')
#  |      FreqDist({'b': 4, 'c': 2, 'a': 1})
#  |
#  |  __and__(self, other)
#  |      Intersection is the minimum of corresponding counts.
#  |
#  |      >>> FreqDist('abbb') & FreqDist('bcc')
#  |      FreqDist({'b': 1})
#  |
#  |  __delitem__(self, key)
#  |      Override ``Counter.__delitem__()`` to invalidate the cached N
#  |
#  |  __ge__ lambda self, other
#  |      # @total_ordering doesn't work here, since the class inherits from a builtin class
#  |
#  |  __gt__ lambda self, other
#  |
#  |  __init__(self, samples=None)
#  |      Construct a new frequency distribution.  If ``samples`` is
#  |      given, then the frequency distribution will be initialized
#  |      with the count of each object in ``samples``; otherwise, it
#  |      will be initialized to be empty.
#  |
#  |      In particular, ``FreqDist()`` returns an empty frequency
#  |      distribution; and ``FreqDist(samples)`` first creates an empty
#  |      frequency distribution, and then calls ``update`` with the
#  |      list ``samples``.
#  |
#  |      :param samples: The samples to initialize the frequency
#  |          distribution with.
#  |      :type samples: Sequence
#  |
#  |  __le__(self, other)
#  |      Return self<=value.
#  |
#  |  __lt__ lambda self, other
#  |
#  |  __or__(self, other)
#  |      Union is the maximum of value in either of the input counters.
#  |
#  |      >>> FreqDist('abbb') | FreqDist('bcc')
#  |      FreqDist({'b': 3, 'c': 2, 'a': 1})
#  |
#  |  __repr__(self)
#  |      Return a string representation of this FreqDist.
#  |
#  |      :rtype: string
#  |
#  |  __setitem__(self, key, val)
#  |      Override ``Counter.__setitem__()`` to invalidate the cached N
#  |
#  |  __str__(self)
#  |      Return a string representation of this FreqDist.
#  |
#  |      :rtype: string
#  |
#  |  __sub__(self, other)
#  |      Subtract count, but keep only results with positive counts.
#  |
#  |      >>> FreqDist('abbbc') - FreqDist('bccd')
#  |      FreqDist({'b': 2, 'a': 1})
#  |
#  |  __unicode__ = __str__(self)
#  |
#  |  copy(self)
#  |      Create a copy of this frequency distribution.
#  |
#  |      :rtype: FreqDist
#  |
#  |  freq(self, sample)
#  |      Return the frequency of a given sample.  The frequency of a
#  |      sample is defined as the count of that sample divided by the
#  |      total number of sample outcomes that have been recorded by
#  |      this FreqDist.  The count of a sample is defined as the
#  |      number of times that sample outcome was recorded by this
#  |      FreqDist.  Frequencies are always real numbers in the range
#  |      [0, 1].
#  |
#  |      :param sample: the sample whose frequency
#  |             should be returned.
#  |      :type sample: any
#  |      :rtype: float
#  |
#  |  hapaxes(self)
#  |      Return a list of all samples that occur once (hapax legomena)
#  |
#  |      :rtype: list
#  |
#  |  max(self)
#  |      Return the sample with the greatest number of outcomes in this
#  |      frequency distribution.  If two or more samples have the same
#  |      number of outcomes, return one of them; which sample is
#  |      returned is undefined.  If no outcomes have occurred in this
#  |      frequency distribution, return None.
#  |
#  |      :return: The sample with the maximum number of outcomes in this
#  |              frequency distribution.
#  |      :rtype: any or None
#  |
#  |  pformat(self, maxlen=10)
#  |      Return a string representation of this FreqDist.
#  |
#  |      :param maxlen: The maximum number of items to display
#  |      :type maxlen: int
#  |      :rtype: string
#  |
#  |  plot(self, *args, **kwargs)
#  |      Plot samples from the frequency distribution
#  |      displaying the most frequent sample first.  If an integer
#  |      parameter is supplied, stop after this many samples have been
#  |      plotted.  For a cumulative plot, specify cumulative=True.
#  |      (Requires Matplotlib to be installed.)
#  |
#  |      :param title: The title for the graph
#  |      :type title: str
#  |      :param cumulative: A flag to specify whether the plot is cumulative (default = False)
#  |      :type title: bool
#  |
#  |  pprint(self, maxlen=10, stream=None)
#  |      Print a string representation of this FreqDist to 'stream'
#  |
#  |      :param maxlen: The maximum number of items to print
#  |      :type maxlen: int
#  |      :param stream: The stream to print to. stdout by default
#  |
#  |  r_Nr(self, bins=None)
#  |      Return the dictionary mapping r to Nr, the number of samples with frequency r, where Nr > 0.
#  |
#  |      :type bins: int
#  |      :param bins: The number of possible sample outcomes.  ``bins``
#  |          is used to calculate Nr(0).  In particular, Nr(0) is
#  |          ``bins-self.B()``.  If ``bins`` is not specified, it
#  |          defaults to ``self.B()`` (so Nr(0) will be 0).
#  |      :rtype: int
#  |
#  |  setdefault(self, key, val)
#  |      Override ``Counter.setdefault()`` to invalidate the cached N
#  |
#  |  tabulate(self, *args, **kwargs)
#  |      Tabulate the given samples from the frequency distribution (cumulative),
#  |      displaying the most frequent sample first.  If an integer
#  |      parameter is supplied, stop after this many samples have been
#  |      plotted.
#  |
#  |      :param samples: The samples to plot (default is all samples)
#  |      :type samples: list
#  |      :param cumulative: A flag to specify whether the freqs are cumulative (default = False)
#  |      :type title: bool
#  |
#  |  unicode_repr = __repr__(self)
#  |
#  |  update(self, *args, **kwargs)
#  |      Override ``Counter.update()`` to invalidate the cached N
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from collections.Counter:
#  |
#  |  __iadd__(self, other)
#  |      Inplace add from another counter, keeping only positive counts.
#  |
#  |      >>> c = Counter('abbb')
#  |      >>> c += Counter('bcc')
#  |      >>> c
#  |      Counter({'b': 4, 'c': 2, 'a': 1})
#  |
#  |  __iand__(self, other)
#  |      Inplace intersection is the minimum of corresponding counts.
#  |
#  |      >>> c = Counter('abbb')
#  |      >>> c &= Counter('bcc')
#  |      >>> c
#  |      Counter({'b': 1})
#  |
#  |  __ior__(self, other)
#  |      Inplace union is the maximum of value from either counter.
#  |
#  |      >>> c = Counter('abbb')
#  |      >>> c |= Counter('bcc')
#  |      >>> c
#  |      Counter({'b': 3, 'c': 2, 'a': 1})
#  |
#  |  __isub__(self, other)
#  |      Inplace subtract counter, but keep only results with positive counts.
#  |
#  |      >>> c = Counter('abbbc')
#  |      >>> c -= Counter('bccd')
#  |      >>> c
#  |      Counter({'b': 2, 'a': 1})
#  |
#  |  __missing__(self, key)
#  |      The count of elements not in the Counter is zero.
#  |
#  |  __neg__(self)
#  |      Subtracts from an empty counter.  Strips positive and zero counts,
#  |      and flips the sign on negative counts.
#  |
#  |  __pos__(self)
#  |      Adds an empty counter, effectively stripping negative and zero counts
#  |
#  |  __reduce__(self)
#  |      helper for pickle
#  |
#  |  elements(self)
#  |      Iterator over elements repeating each as many times as its count.
#  |
#  |      >>> c = Counter('ABCABC')
#  |      >>> sorted(c.elements())
#  |      ['A', 'A', 'B', 'B', 'C', 'C']
#  |
#  |      # Knuth's example for prime factors of 1836:  2**2 * 3**3 * 17**1
#  |      >>> prime_factors = Counter({2: 2, 3: 3, 17: 1})
#  |      >>> product = 1
#  |      >>> for factor in prime_factors.elements():     # loop over factors
#  |      ...     product *= factor                       # and multiply them
#  |      >>> product
#  |      1836
#  |
#  |      Note, if an element's count has been set to zero or is a negative
#  |      number, elements() will ignore it.
#  |
#  |  most_common(self, n=None)
#  |      List the n most common elements and their counts from the most
#  |      common to the least.  If n is None, then list all element counts.
#  |
#  |      >>> Counter('abcdeabcdabcaba').most_common(3)
#  |      [('a', 5), ('b', 4), ('c', 3)]
#  |
#  |  subtract(*args, **kwds)
#  |      Like dict.update() but subtracts counts instead of replacing them.
#  |      Counts can be reduced below zero.  Both the inputs and outputs are
#  |      allowed to contain zero and negative counts.
#  |
#  |      Source can be an iterable, a dictionary, or another Counter instance.
#  |
#  |      >>> c = Counter('which')
#  |      >>> c.subtract('witch')             # subtract elements from another iterable
#  |      >>> c.subtract(Counter('watch'))    # subtract elements from another counter
#  |      >>> c['h']                          # 2 in which, minus 1 in witch, minus 1 in watch
#  |      0
#  |      >>> c['w']                          # 1 in which, minus 1 in witch, minus 1 in watch
#  |      -1
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from collections.Counter:
#  |
#  |  fromkeys(iterable, v=None) from builtins.type
#  |      Returns a new dict with keys from iterable and values equal to value.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from collections.Counter:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from builtins.dict:
#  |
#  |  __contains__(self, key, /)
#  |      True if D has a key k, else False.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  items(...)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(...)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  values(...)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from builtins.dict:
#  |
#  |  __hash__ = None

# %%
pah_freq.tabulate(10)
# Out:
#   pad andar  abar bawēd čiyōn   u-š   rāy   ast  harw estēd
# 19534  5979  4963  4604  3774  3623  2915  2660  2478  2428

# %% [markdown]
# ### Bigrams

# %%
pah_bi = nltk.ngrams(pah_toks_clean, 2)
pah_bi_freq = nltk.FreqDist(pah_bi)
pah_bi_freq.most_common(10)
# Out:
# [(('nigēz', 'weh-dēn'), 374),
#  (('weh-dēn', 'hād'), 361),
#  (('u-šān', 'ēn-iz'), 341),
#  (('ōwōn', 'dāšt'), 339),
#  (('ēn-iz', 'ōwōn'), 337),
#  (('pad', 'tan'), 312),
#  (('guft', 'estēd'), 275),
#  (('kerd', 'estēd'), 260),
#  (('bawēd', 'pad'), 251),
#  (('u-š', 'pad'), 249)]

# %% [markdown]
# ### Trigrams

# %%
pah_tri = nltk.ngrams(pah_toks_clean, 3)
pah_tri_freq = nltk.FreqDist(pah_tri)
pah_tri_freq.most_common(10)
# Out:
# [(('nigēz', 'weh-dēn', 'hād'), 355),
#  (('u-šān', 'ēn-iz', 'ōwōn'), 331),
#  (('ēn-iz', 'ōwōn', 'dāšt'), 328),
#  (('ēdōn', 'bawēd', 'čiyōn'), 88),
#  (('bawēd', 'ēd-iz', 'rāy'), 80),
#  (('menišn', 'gōwišn', 'kunišn'), 73),
#  (('gōwēd', 'Srōš-ahlaw', 'Ādur-yazd'), 73),
#  (('Srōš-ahlaw', 'Ādur-yazd', 'ruwān'), 72),
#  (('frazaft', 'pad', 'drōd'), 69),
#  (('pad', 'drōd', 'šādīh'), 62)]

# %% [markdown]
# ### Quad-grams

# %%
pah_quad = nltk.ngrams(pah_toks_clean, 4)
pah_quad_freq = nltk.FreqDist(pah_quad)
pah_quad_freq.most_common(10)
# Out:
# [(('u-šān', 'ēn-iz', 'ōwōn', 'dāšt'), 326),
#  (('gōwēd', 'Srōš-ahlaw', 'Ādur-yazd', 'ruwān'), 63),
#  (('mēnōy', 'xrad', 'passox', 'kerd'), 62),
#  (('frazaft', 'pad', 'drōd', 'šādīh'), 59),
#  (('pursīd', 'dānāg', 'mēnōy', 'xrad'), 59),
#  (('Srōš-ahlaw', 'Ādur-yazd', 'ruwān', 'druwand'), 41),
#  (('u-m', 'pursīd', 'tan', 'wināh'), 41),
#  (('pad', 'drōd', 'šādīh', 'rāmišn'), 40),
#  (('pursīd', 'tan', 'wināh', 'kerd'), 39),
#  (('wināh', 'kerd', 'ruwān', 'ōwōn'), 34)]

# %%
pah_tri_phrases = pah_tri_freq.most_common()
pah_tri_phrases = [x for x in pah_tri_phrases if x[1]>1]
pah_tri_phrases
# Out:
# [(('nigēz', 'weh-dēn', 'hād'), 355),
#  (('u-šān', 'ēn-iz', 'ōwōn'), 331),
#  (('ēn-iz', 'ōwōn', 'dāšt'), 328),
#  (('ēdōn', 'bawēd', 'čiyōn'), 88),
#  (('bawēd', 'ēd-iz', 'rāy'), 80),
#  (('menišn', 'gōwišn', 'kunišn'), 73),
#  (('gōwēd', 'Srōš-ahlaw', 'Ādur-yazd'), 73),
#  (('Srōš-ahlaw', 'Ādur-yazd', 'ruwān'), 72),
#  (('frazaft', 'pad', 'drōd'), 69),
#  (('pad', 'drōd', 'šādīh'), 62),
#  (('mēnōy', 'xrad', 'passox'), 62),
#  (('xrad', 'passox', 'kerd'), 62),
#  (('pursīd', 'dānāg', 'mēnōy'), 60),
#  (('dānāg', 'mēnōy', 'xrad'), 60),
#  (('ast', 'ēdōn', 'gōwēd'), 55),
#  (('humad', 'hūxt', 'huwaršt'), 52),
#  (('u-m', 'dīd', 'ruwān'), 52),
#  (('tan', 'wināh', 'kerd'), 49),
#  (('gōwēd', 'pad', 'dēn'), 45),
#  (('Ādur-yazd', 'ruwān', 'druwand'), 44),
#  (('xwāstag', 'pad', 'stūrīh'), 43),
#  (('pad', 'tan', 'pasēn'), 42),
#  (('u-m', 'pursīd', 'tan'), 41),
#  (('pursīd', 'tan', 'wināh'), 41),
#  (('čiyōn', 'man', 'dānam'), 41),
#  (('drōd', 'šādīh', 'rāmišn'), 40),
#  (('andar', 'ham', 'dar'), 40),
#  (('u-š', 'guft', 'Ohrmazd'), 39),
#  (('yašt', 'kerd', 'estēd'), 38),
#  (('kerd', 'ruwān', 'ōwōn'), 35),
#  (('kē-š', 'pad', 'gētīy'), 35),
#  (('čiyōn', 'dēn', 'gōwēd'), 35),
#  (('wināh', 'kerd', 'ruwān'), 34),
#  (('ōwōn', 'garān', 'pādifrāh'), 34),
#  (('ristāxēz', 'tan', 'pasēn'), 34),
#  (('pad', 'petīt', 'bawēd'), 32),
#  (('mar', 'druwand', 'sāstār'), 32),
#  (('pad', 'nām', 'yazdān'), 31),
#  (('garān', 'pādifrāh', 'barēd'), 31),
#  (('tis', 'andar', 'nēst'), 31),
#  (('dīd', 'ruwān', 'mard-ēw'), 30),
#  (('ruwān', 'ōwōn', 'garān'), 30),
#  (('Yōšt', 'Friyān', 'guft'), 30),
#  (('māh', 'frawardīn', 'rōz'), 30),
#  (('kē-šān', 'pad', 'gētīy'), 29),
#  (('gēhān', 'barišn', 'ēdōn'), 29),
#  (('barišn', 'ēdōn', 'barišn'), 29),
#  (('frawardīn', 'rōz', 'hordad'), 29),
#  (('pad', 'baxt', 'šawēd'), 28),
#  (('ruwān', 'druwand', 'mard'), 26),
#  (('harw', 'kas', 'pad'), 26),
#  (('Ādur-yazd', 'ruwān', 'awēšān'), 25),
#  (('pad', 'xwēš', 'tan'), 25),
#  (('andar', 'nēst', 'rāy'), 25),
#  (('nēst', 'rāy', 'ǰuttar'), 25),
#  (('pad', 'tan', 'mehmān'), 25),
#  (('gōwēd', 'kū-m', 'xwāstag'), 25),
#  (('bōy', 'ēdōn', 'čiyōn'), 25),
#  (('pad', 'gōmēz', 'šōyišn'), 25),
#  (('guft', 'estēd', 'pad'), 24),
#  (('xwāstag', 'pad', 'xwēšīh'), 24),
#  (('ōwōn', 'dāšt', 'harw'), 24),
#  (('hammōxt', 'bawēd', 'ēd-iz'), 24),
#  (('druwand', 'sāstār', 'murdagān'), 24),
#  (('druwand', 'mard', 'kē-š'), 23),
#  (('mard', 'kē-š', 'pad'), 23),
#  (('dēn', 'weh', 'mazdēsnān'), 23),
#  (('xwāstag', 'man', 'xwēš'), 23),
#  (('bāš', 'mar', 'druwand'), 23),
#  (('sāstār', 'murdagān', 'dōšox'), 23),
#  (('bawēd', 'ayāb', 'passox'), 23),
#  (('D10a', 'K43b', 'D10a'), 23),
#  (('ēg-im', 'dīd', 'ruwān'), 22),
#  (('dādār', 'Ohrmazd', 'rāyōmand'), 22),
#  (('Ohrmazd', 'rāyōmand', 'xwarrahōmand'), 22),
#  (('ǰud', 'ǰud', 'pad'), 22),
#  (('bawēd', 'čiyōn', 'ka-š'), 22),
#  (('pad', 'kār', 'kerbag'), 22),
#  (('xwēš', 'tan', 'pad'), 22),
#  (('tan', 'pad', 'zanīh'), 22),
#  (('zīndagān', 'pad-škōh', 'bāš'), 22),
#  (('pad-škōh', 'bāš', 'mar'), 22),
#  (('murdagān', 'dōšox', 'ōft'), 22),
#  (('pad', 'hamāg', 'kār'), 21),
#  (('u-š', 'ēn-iz', 'guft'), 21),
#  (('Friyān', 'guft', 'zīndagān'), 21),
#  (('spāsdār', 'ham', 'dādār'), 21),
#  (('K43b', 'D10a', 'K43b'), 21),
#  (('pad', 'menišn', 'gōwišn'), 20),
#  (('čiyōn', 'gōwēd', 'pad'), 20),
#  (('ēg-iš', 'dādestān', 'čiyōn'), 20),
#  (('stāyēm', 'azbayēm', 'dādār'), 20),
#  (('pad', 'dēn', 'gōwēd'), 19),
#  (('Yazdgerd', 'šāhān', 'šāh'), 19),
#  (('pad', 'harw', 'gāh'), 19),
#  (('dādār', 'Ohrmazd', 'pad'), 19),
#  (('ōwōn', 'dāšt', 'mardōmān'), 19),
#  (('ēd-iz', 'rāy', 'čē-š'), 19),
#  (('gōwēd', 'xwāstag', 'man'), 19),
#  (('guft', 'zīndagān', 'pad-škōh'), 19),
#  (('čiyōn', 'ka-š', 'pad'), 19),
#  (('azbayēm', 'dādār', 'Ohrmazd'), 19),
#  (('ka-š', 'frāz', 'brēhēnīd'), 19),
#  (('ham-dādestān', 'būd', 'hēnd'), 18),
#  (('kerd', 'estēd', 'u-š'), 18),
#  (('pad', 'dast', 'xwēš'), 18),
#  (('mad', 'estēd', 'pad'), 18),
#  (('andar', 'gēhān', 'pad'), 18),
#  (('kerd', 'estēd', 'pad'), 18),
#  (('pad', 'bahr', 'bahr'), 18),
#  (('agar-iš', 'tis', 'andar'), 18),
#  (('dīd', 'ruwān', 'zan-ēw'), 17),
#  (('Gannāg', 'Mēnōy', 'pad'), 17),
#  (('ahlāyīh', 'ābādīh', 'pahlom'), 17),
#  (('ōwōn', 'bawēd', 'čiyōn'), 17),
#  (('ōwōn', 'homānāg', 'čiyōn'), 17),
#  (('ruwān', 'rāy', 'paydāg'), 17),
#  (('abāg', 'guft', 'gōwēd'), 17),
#  (('dādār', 'weh', 'abzōnīg'), 17),
#  (('rāyōmand', 'xwarrahōmand', 'amahrspandān'), 17),
#  (('ruwān', 'druwand', 'zan'), 16),
#  (('ruwān', 'awēšān', 'druwandān'), 16),
#  (('menēd', 'gōwēd', 'kunēd'), 16),
#  (('māh', 'Frawardīn', 'rōz'), 16),
#  (('andar', 'tan', 'mardōmān'), 16),
#  (('ruwān', 'dōšāram', 'rāy'), 16),
#  (('pad', 'yazdān', 'kāmag'), 16),
#  (('šāhān', 'šāh', 'Ohrmazdān'), 16),
#  (('pad', 'yazdān', 'kām'), 16),
#  (('pad', 'mad', 'estēd'), 16),
#  (('mardōm', 'nigēz', 'weh-dēn'), 16),
#  (('ōwōn', 'dāšt', 'pad'), 16),
#  (('kār', 'kerbag', 'kerdan'), 16),
#  (('pad', 'pišag', 'šōyišn'), 16),
#  (('rēman', 'bawēd', 'ayāb'), 16),
#  (('pad', 'humad', 'hūxt'), 15),
#  (('mēnōyān', 'yazdān', 'gētīyān'), 15),
#  (('weh', 'dēn', 'mazdēsnān'), 15),
#  (('būd', 'hēnd', 'u-šān'), 15),
#  (('pad', 'hamāg', 'gēhān'), 15),
#  (('padiš', 'andar', 'āyēd'), 15),
#  (('ābādīh', 'pahlom', 'ast'), 15),
#  (('harw', 'gāh', 'zamān'), 15),
#  (('čiyōn', 'abāyēd', 'kerdan'), 15),
#  (('āsrōnīh', 'artēštārīh', 'wāstaryōšīh'), 15),
#  (('pad', 'awindišnīh', 'hunsand'), 15),
#  (('pad', 'tan', 'xwēš'), 15),
#  (('paydāgīhist', 'wazurg', 'abdīh'), 15),
#  (('ēdōn', 'čiyōn', 'bōy'), 15),
#  (('Ērān', 'dehān', 'man'), 15),
#  (('u-m', 'burzišnīg', 'sahist'), 14),
#  (('zan', 'kē-š', 'pad'), 14),
#  (('pad', 'ham', 'zamān'), 14),
#  (('andar', 'harw', 'axwān'), 14),
#  (('andar', 'Ērān', 'šahr'), 14),
#  (('pad', 'yazdān', 'amahrspandān'), 14),
#  (('yazdān', 'amahrspandān', 'kāmag'), 14),
#  (('būd', 'dastwar', 'kē-š'), 14),
#  (('kerd', 'bawēd', 'ēd-iz'), 14),
#  (('šāyēd', 'ayāb', 'passox'), 14),
#  (('frōd', 'grift', 'estēd'), 14),
#  (('tan', 'pasēn', 'pad'), 13),
#  (('yazdān', 'mēnōyān', 'yazdān'), 13),
#  (('zamīg', 'urwar', 'gōspand'), 13),
#  (('pad', 'nām', 'dādār'), 13),
#  (('tan', 'pasēn', 'bawēd'), 13),
#  (('čiyōn', 'pad', 'dēn'), 13),
#  (('pad', 'hamāg', 'zamīg'), 13),
#  (('pad', 'harw', 'kas'), 13),
#  (('dēn', 'guft', 'estēd'), 13),
#  (('pad', 'frārōnīh', 'dārēd'), 13),
#  (('bawād', 'ēdōn', 'bawād'), 13),
#  (('amāh', 'rāy', 'pad'), 13),
#  (('pad', 'mēnōy', 'ruwān'), 13),
#  (('dādār', 'Ohrmazd', 'amahrspandān'), 13),
#  (('pad', 'nām', 'yazd'), 13),
#  (('man', 'Ohrmazd', 'ham'), 13),
#  (('dast', 'xwēš', 'kerd'), 13),
#  (('pad', 'dēn', 'mazdēsnān'), 13),
#  (('Ohrmazd', 'Zarduxšt', 'guft'), 13),
#  (('druz', 'astag', 'mānī'), 13),
#  (('yaθā', 'ahū', 'vairiiō'), 13),
#  (('rāh', 'dārēd', 'andar'), 13),
#  (('ēn-iz', 'kū-š', 'pad'), 13),
#  (('ēd-iz', 'rāy', 'pad'), 13),
#  (('harw', 'kas', 'dānēd'), 13),
#  (('xwāstag', 'ruwān', 'rāy'), 13),
#  (('nasāy', 'sag', 'dīd'), 13),
#  (('gōwēd', 'rēdag', 'anōšag'), 13),
#  (('dehān', 'man', 'Ohrmazd-dād'), 13),
#  (('Tab', '-WNyt', '-WNyt̨'), 13),
#  (('-ym', '-ym', '-ym'), 13),
#  (('February', '2016', '8:07'), 13),
#  (('DĒNKARD', 'BOOK', 'CHAPTER'), 13),
#  (('awiš', 'mad', 'estēd'), 12),
#  (('pad', 'ēwēnag', 'dīd'), 12),
#  (('abar', 'xwēš', 'tan'), 12),
#  (('druwand', 'zan', 'kē-š'), 12),
#  (('ast', 'rāh', 'ahlāyīh'), 12),
#  (('mayān', 'zrēy', 'Frāxkerd'), 12),
#  (('pahlom', 'axwān', 'rasēd'), 12),
#  (('yazdān', 'kāmag', 'bawād'), 12),
#  (('hamāg', 'dām', 'dahišn'), 12),
#  (('dām', 'dahišn', 'Ohrmazd'), 12),
#  (('dēn', 'framūd', 'estēd'), 12),
#  (('čiyōn', 'guft', 'estēd'), 12),
#  (('xwēš', 'tan', 'andar'), 12),
#  (('ēn-iz', 'paydāg', 'Ohrmazd'), 12),
#  (('bawēd', 'čiyōn', 'pad'), 12),
#  (('aziš', 'guft', 'bawēd'), 12),
#  (('abāz', 'dāštan', 'tuwān'), 12),
#  (('mān', 'wis', 'zand'), 12),
#  (('wis', 'zand', 'deh'), 12),
#  (('pad', 'zanīh', 'mard'), 12),
#  (('pad', 'xwēšīh', 'Ohrmazd'), 12),
#  (('dārēd', 'ēd-iz', 'rāy'), 12),
#  (('harw', 'kas-ēw', 'dānēd'), 12),
#  (('guft', 'anōšag', 'bawēd'), 12),
#  (('gōwēd', 'kū-m', 'pad'), 12),
#  (('pad', 'windišn', 'pādixšāy'), 12),
#  (('ǰuttar', 'bawēd', 'čiyōn'), 12),
#  (('pad', 'zamān', 'bawēd'), 12),
#  (('baršnūm', 'čiyōn', 'nibišt'), 12),
#  (('pad', 'rāst', 'dāšt'), 12),
#  (('rēdag', 'anōšag', 'bawēd'), 12),
#  (('ka-š', 'nasāy', 'abar'), 12),
#  (('pad', 'gyāg', 'pāk'), 12),
#  (('III', 'III', 'III'), 12),
#  (('Molé', 'Problème', 'des'), 12),
#  (('Problème', 'des', 'sectes'), 12),
#  (('pad', 'weh', 'dēn'), 11),
#  (('pad', 'kerbag', 'kerdan'), 11),
#  (('star', 'māh', 'xwaršēd'), 11),
#  (('ōwōn', 'pādifrāh', 'barēd'), 11),
#  (('awēšān', 'druwandān', 'kē-šān'), 11),
#  (('pad', 'dast', 'dārēd'), 11),
#  (('xwēšīh', 'man', 'rasēd'), 11),
#  (('andar', 'zrēy', 'Frāxkerd'), 11),
#  (('pad', 'ēwēnag', 'pad'), 11),
#  (('xwēšīh', 'xwēš', 'rāy'), 11),
#  (('man', 'dēn', 'bandag'), 11),
#  (('bawēd', 'Spitāmān', 'Zardušt'), 11),
#  (('rāy', 'guft', 'estēd'), 11),
#  (('ēdōn', 'guft', 'estēd'), 11),
#  (('pad', 'čār', 'tuwān'), 11),
#  (('ēdōn', 'homānāg', 'čiyōn'), 11),
#  (('ka-š', 'saxwan', 'āšnūd'), 11),
#  (('abar', 'guft', 'bawēd'), 11),
#  (('padīruftan', 'menīdan', 'guftan'), 11),
#  (('menīdan', 'guftan', 'warzīdan'), 11),
#  (('ōwōn', 'dāšt', 'Ohrmazd'), 11),
#  (('bawēd', 'pad', 'harw'), 11),
#  (('Ohrmazd', 'mēnōy', 'abzōnīg'), 11),
#  (('pad', 'yazišn', 'yazdān'), 11),
#  (('Pusānweh', 'Āzād-mardān', 'guft'), 11),
#  (('200', 'wahāg', 'arzēd'), 11),
#  (('bawēd', 'čiyōn', 'gōwēd'), 11),
#  (('rāy', 'paydāg', 'kunēd'), 11),
#  (('zan', 'frazend', 'pādixšāyīhā'), 11),
#  (('pad', 'baršnūm', 'čiyōn'), 11),
#  (('paydāg', 'Ohrmazd', 'Zarduxšt'), 11),
#  (('murd', 'estēd', 'čiyōn'), 11),
#  (('dīd', 'ruwān', 'awēšān'), 10),
#  (('andar', 'gētīy', 'pad'), 10),
#  (('ruwān', 'ōwōn', 'pādifrāh'), 10),
#  (('druwandān', 'kē-šān', 'pad'), 10),
#  (('hamāg', 'yazdān', 'mēnōyān'), 10),
#  (('nām', 'dādār', 'Ohrmazd'), 10),
#  (('u-š', 'dād', 'hayārīh'), 10),
#  (('māh', 'Day', 'rōz'), 10),
#  (('pēš', 'Ohrmazd', 'xwadāy'), 10),
#  (('Ohrmazd', 'abāg', 'amahrspandān'), 10),
#  (('Frawardīn', 'rōz', 'Ohrmazd'), 10),
#  (('abar', 'mad', 'estēd'), 10),
#  (('pad', 'Abestāg', 'paydāg'), 10),
#  (('nām', 'būd', 'hēnd'), 10),
#  (('xwadāyīh', 'Ērān', 'šahr'), 10),
#  (('brād', 'būd', 'hēnd'), 10),
#  (('amahrspandān', 'kāmag', 'bawād'), 10),
#  (('harw', 'rōz', 'bār'), 10),
#  (('bawēd', 'ayāb', 'pad'), 10),
#  (('kerbag', 'ayāb', 'wināh'), 10),
#  (('ōwōn', 'dāšt', 'mardōm'), 10),
#  (('harw', 'kār', 'kerbag'), 10),
#  (('padīrag', 'ahlaw', 'Zarduxšt'), 10),
#  (('padīrag', 'ahlaw', 'saēn'), 10),
#  (('handarzēnīd', 'druz', 'astag'), 10),
#  (('padīrag', 'ahlāyīg', 'ārāstār'), 10),
#  (('ahlāyīg', 'ārāstār', 'ādurbād'), 10),
#  (('fraškerd', 'tan', 'pasēn'), 10),
#  (('būd', 'guft', 'pad'), 10),
#  (('rāy', 'guft', 'bawēd'), 10),
#  (('pad', 'tan', 'mardōmān'), 10),
#  (('wazurg', 'abdīh', 'wasān'), 10),
#  (('u-š', 'guft', 'Zarduxšt'), 10),
#  (('ēn-iz', 'abar', 'gōwēd'), 10),
#  (('bīm', 'pad', 'tan'), 10),
#  (('kerdan', 'andar', 'ham-dar'), 10),
#  (('bawēd', 'andar', 'ham-dar'), 10),
#  (('nasāy', 'abar', 'rasīd'), 10),
#  (('guft-iš', 'Ohrmazd', 'Spitāmān'), 10),
#  (('Ohrmazd', 'dād', 'bawēd'), 10),
#  (('kunēd', 'ēd-iz', 'rāy'), 10),
#  (('gyāg-ēw', 'nibišt', 'gōwēd'), 10),
#  (('rāy', 'paydāg', 'kerd'), 10),
#  (('guft', 'gōwēd', 'kū-m'), 10),
#  (('ka-š', 'pad', 'dast'), 10),
#  (('pēš', 'padiš', 'andar'), 10),
#  (('agar', 'ašmāh', 'bayān'), 10),
#  (('ham', 'wāhmān', 'wāhmān'), 10),
#  (('ham', 'dādār', 'weh'), 10),
#  (('pāy', 'nēm', '15-om'), 10),
#  (('šāyēd', 'ayāb', 'pad'), 10),
#  (('Nasuš', 'abar', 'dwārēd'), 10),
#  (('KabMb', 'mlt-', 'KabMb'), 10),
#  (('BOOK', 'CHAPTER', 'TEXT'), 10),
#  (('CHAPTER', 'TEXT', 'DĒNKARD'), 10),
#  (('TEXT', 'DĒNKARD', 'BOOK'), 10),
#  (('ēdōn', 'bawād', 'ēdōntar'), 9),
#  (('bawād', 'ēdōntar', 'bawād'), 9),
#  (('bawād', 'frazaft', 'pad'), 9),
#  (('šnāyišn', 'dādār', 'Ohrmazd'), 9),
#  (('dām', 'Ohrmazd', 'pad'), 9),
#  (('abāg', 'Ganāg', 'Mēnōy'), 9),
#  (('pad', 'ham', 'ēwēnag'), 9),
#  (('harw', 'rōz', 'pad'), 9),
#  (('pad', 'rōz', 'keh'), 9),
#  (('būd', 'hēnd', 'čiyōn'), 9),
#  (('pad', 'paydāgīh', 'dēn'), 9),
#  (('pad', 'harw', 'tis'), 9),
#  (('rāmēnīd', 'ayāb', 'bēšīd'), 9),
#  (('Ērān', 'šahr', 'pad'), 9),
#  (('fraškerd', 'andar', 'axwān'), 9),
#  (('pad', 'kāmag', 'xwēš'), 9),
#  (('Marzbān', 'Frēdōn', 'Wāhrom'), 9),
#  (('ēdōn', 'čiyōn', 'guft'), 9),
#  (('ēdōn', 'bawād', 'ēdōntar-iz'), 9),
#  (('amahrspandān', 'abārīg', 'yazdān'), 9),
#  (('wināh', 'ī-š', 'kerd'), 9),
#  (('fradom', 'didīgar', 'sidīgar'), 9),
#  (('andar', 'mān', 'ātaxšān'), 9),
#  (('gāh', 'dārēd', 'ast'), 9),
#  (('andar', 'harw', 'gāh'), 9),
#  (('pad', 'nērōg', 'xrad'), 9),
#  (('xwēš', 'šāyēd', 'kerdan'), 9),
#  (('pad', 'tan', 'mard'), 9),
#  (('harw', 'kas', 'rāy'), 9),
#  (('wināh', 'bun', 'bawēd'), 9),
#  (('pad', 'kār', 'abāyēd'), 9),
#  (('čim', 'passox', 'hād'), 9),
#  (('pad', 'xwāyišn', 'pursišn'), 9),
#  (('pahrēz', 'wizīr', 'padiš'), 9),
#  (('sag', 'nimāyišn', 'pad'), 9),
#  (('ōwōn', 'dāšt', 'dēn'), 9),
#  (('ōwōn', 'dāšt', 'mard'), 9),
#  (('abar', 'grād', 'abar'), 9),
#  (('Spitāmān', 'ahlaw', 'Zarduxšt'), 9),
#  (('ast', 'pahlom', 'ābādīh'), 9),
#  (('pahlom', 'ābādīh', 'ahlāyīh'), 9),
#  (('dahēd', 'ēd-iz', 'rāy'), 9),
#  (('pad', 'zanīh', 'dād'), 9),
#  (('būd', 'guft', 'kū-š'), 9),
#  (('arz', '200', 'wahāg'), 9),
#  (('abāz', 'bun', 'šawēd'), 9),
#  (('ēdōn', 'gōwēd', 'āt̰'), 9),
#  (('ašmāh', 'bayān', 'sahēd'), 9),
#  (('andar', 'bun', 'nāmag'), 9),
#  (('pad', 'gyāg', 'tanābuhl'), 9),
#  (('pad', 'sāl-drahnāy', 'margarzān'), 9),
#  (('abāyēd', 'kerdan', 'passox'), 9),
#  (('hixr', 'murdagān', 'padiš'), 9),
#  (('pad', 'čāštag', 'Pyšksyl'), 9),
#  (('pay', 'nēm', '15om'), 9),
#  (('ēg-iš', 'wināh', 'čand'), 9),
#  (('TabD', 'mlt-', 'TabD'), 9),
#  (('K43b', 'D10a', 'D10a'), 9),
#  (('crossed', 'out', 'and'), 9),
#  (('K43b', 'MR.', 'K43b'), 9),
#  (('All', '-x1', 'All'), 9),
#  (('pad', 'tis', 'yazdān'), 8),
#  (('Ohrmazd', 'xwadāy', 'amahrspandān'), 8),
#  (('mad', 'ham', 'u-m'), 8),
#  (('būd', 'ham', 'u-t'), 8),
#  (('pad', 'dast', 'frāz'), 8),
#  (('pērōz', 'bawād', 'xwarrah'), 8),
#  (('Ohrmazd', 'pad', 'tan'), 8),
#  (('Ohrmazd', 'pad', 'harwisp-āgāhīh'), 8),
#  (('pad', 'dāmān', 'Ohrmazd'), 8),
#  (('pad', 'dēn', 'paydāg'), 8),
#  (('u-š', 'xwēš', 'tan'), 8),
#  (('pad', 'mard', 'kerb'), 8),
#  (('māh', 'Spandarmad', 'rōz'), 8),
#  (('rōz', 'šab', 'rāst'), 8),
#  (('paydāg', 'būd', 'hēnd'), 8),
#  (('abar', 'rust', 'hēnd'), 8),
#  (('andar', 'dēn', 'mazdēsnān'), 8),
#  (('rāy', 'gōwēd', 'kū-š'), 8),
#  (('hēnd', 'u-šān', 'pad'), 8),
#  (('pad', 'pušt', 'gāw'), 8),
#  (('pad', 'tan', 'dārēd'), 8),
#  (('rāy', 'gōwēd', 'pad'), 8),
#  (('pad', 'dēn', 'yazdān'), 8),
#  (('mad', 'estēd', 'rāy'), 8),
#  (('pad', 'gētīy', 'tan'), 8),
#  (('pad', 'dād', 'nihād'), 8),
#  (('u-š', 'pas', 'pad'), 8),
#  (('dušmad', 'duš-hūxt', 'duš-huwaršt'), 8),
#  (('zan', 'frazend', 'xwāstag'), 8),
#  (('Ōšīdar', 'Ōšīdarmāh', 'Sōšāns'), 8),
#  (('Zarduxšt', 'Ohrmazd', 'pursīd'), 8),
#  (('mowbedān', 'mowbed', 'būd'), 8),
#  (('andar', 'dēn', 'guft'), 8),
#  (('man', 'nibištār', 'ham'), 8),
#  (('dēn', 'nēkīh', 'rasād'), 8),
#  (('nibišt', 'pad', 'yazdān'), 8),
#  (('abēzag', 'weh', 'dēn'), 8),
#  (('bawād', 'ēdōntar-iz', 'bawād'), 8),
#  (('pad', 'kerbag', 'mizd'), 8),
#  (('ruwān', 'druwand', 'bawād'), 8),
#  (('guft', 'estēd', 'andar'), 8),
#  (('ruwān', 'andar', 'rāh'), 8),
#  (('mardōmān', 'andar', 'gētīy'), 8),
#  (('fraškerd', 'pad', 'kāmag'), 8),
#  (('pad', 'kāmag', 'andar'), 8),
#  (('pad', 'stūrīh', 'šāyēd'), 8),
#  (('mard', 'abāg', 'zan'), 8),
#  (('aziš', 'šāyēd', 'būd'), 8),
#  (('pad', 'ham', 'gyāg'), 8),
#  (('dastwar', 'kē-š', 'guft'), 8),
#  (('druz', 'rāh', 'dārēd'), 8),
#  (('harw', 'tis', 'pad'), 8),
#  (('pad', 'abāz', 'dāštan'), 8),
#  (('kār', 'kerbag', 'pad'), 8),
#  (('mad', 'estēd', 'hunsand'), 8),
#  (('ī-š', 'kerd', 'estēd'), 8),
#  (('pad', 'wehīh', 'wattarīh'), 8),
#  (('Gannāg', 'Mēnōy', 'dēwān'), 8),
#  (('ǰud', 'ǰud', 'xwēš'), 8),
#  (('andar', 'mardōm', 'kerdan'), 8),
#  (('hamāg', 'mardōm', 'pad'), 8),
#  (('spāsdār', 'pad', 'awindišnīh'), 8),
#  (('awindišnīh', 'hunsand', 'abēš'), 8),
#  (('hamāg', 'kār', 'dādestān'), 8),
#  (('nohom', 'dahom', 'sadōzim'), 8),
#  (('mardōm', 'andar', 'gēhān'), 8),
#  (('akōman', 'andarg', 'menišn'), 8),
#  (('xwaršēd', 'māh', 'starān'), 8),
#  (('pad', 'xūb', 'dāšt'), 8),
#  (('dāšt', 'harw', 'kas'), 8),
#  (('ōwōn', 'dāšt', 'tis'), 8),
#  (('harw', 'gāh', 'pad'), 8),
#  (('pad', 'bahr', 'xwēš'), 8),
#  (('tis', 'abēr', 'nēk'), 8),
#  (('u-š', 'gāh', 'pad'), 8),
#  (('ēdar', 'paydāgīhist', 'wazurg'), 8),
#  (('ahlāyīh', 'ābādīh', 'ast'), 8),
#  (('ābādīh', 'ast', 'pahlom'), 8),
#  (('ahlāyīh', 'ast', 'pahlom'), 8),
#  (('ahlāyīh', 'pahlom', 'ast'), 8),
#  (('ābādīh', 'ahlāyīh', 'ast'), 8),
#  (('ābādīh', 'pahlom', 'ahlāyīh'), 8),
#  (('pahlom', 'ahlāyīh', 'ast'), 8),
#  (('pahlom', 'ast', 'ahlāyīh'), 8),
#  (('mard', 'pad', 'āgenēn'), 8),
#  (('abar', 'dād', 'Ohrmazd'), 8),
#  (('pahlom', 'ābādīh', 'ast'), 8),
#  (('ast', 'ahlāyīh', 'ābādīh'), 8),
#  (('sag', 'dīd', 'pad'), 8),
#  (('rēman', 'būd', 'estēd'), 8),
#  (('hamāg', 'dām', 'Ohrmazd'), 8),
#  (('yazišn', 'yazdān', 'kerdan'), 8),
#  (('xwēšīh', 'Ohrmazd', 'dārēd'), 8),
#  (('duxt', 'pad', 'duxtarīh'), 8),
#  (('duxt', 'pad', 'zanīh'), 8),
#  (('gyāg-ēw', 'nibišt', 'pad'), 8),
#  (('wahāg', 'arzēd', 'xwēš'), 8),
#  (('u-š', 'zan', 'frazend'), 8),
#  (('pad', 'zanīh', 'kunēd'), 8),
#  (('zēndān', 'kerd', 'estēd'), 8),
#  (('bār', 'pad', 'gōmēz'), 8),
#  (('ēn-iz', 'pursīd', 'Ohrmazd'), 8),
#  (('ā-š', 'tanābuhl-ēw', 'wināh'), 8),
#  (('u-š', 'yašt', 'kerd'), 8),
#  (('kerbag', 'wēš', 'wināh'), 8),
#  (('wināh', 'pad', 'petīt'), 8),
#  (('gāh', 'pēš', 'padiš'), 8),
#  (('spāhbed', 'nēw', 'zarēr'), 8),
#  (('abar', 'āxēzēd', 'abāz'), 8),
#  (('passandīd', 'u-š', 'pad'), 8),
#  (('u-š', 'pad', 'rāst'), 8),
#  (('bun', 'nāmag', 'u-tān'), 8),
#  (('ēg-iš', 'wināh', 'bun'), 8),
#  (('abāg', 'zan', 'daštān'), 8),
#  (('tanābuhl', 'pad', 'bun'), 8),
#  (('THE', 'PERFORMANCE', 'THE'), 8),
#  (('maγ', 'pad', 'gōmēz'), 8),
#  (('TabD', '-WNt', 'TabD'), 8),
#  (('KTM', 'Yyyt-', 'TdKTM'), 8),
#  (('-yt', '-yt', '-yt'), 8),
#  (('dast', 'frāz', 'grift'), 7),
#  (('ham', 'u-m', 'dīd'), 7),
#  (('pas', 'Srōš-ahlaw', 'Ādur-yazd'), 7),
#  (('mad', 'hēnd', 'pad'), 7),
#  (('u-m', 'pursīd', 'awēšān'), 7),
#  (('kerbag', 'kerdan', 'tuxšāg'), 7),
#  (('ruwān', 'awēšān', 'kē-šān'), 7),
#  (('pad', 'gētīy', 'dīd'), 7),
#  (('ruwān', 'mard-ēw', 'kē-š'), 7),
#  (('dāšt', 'mardōmān', 'tis'), 7),
#  (('u-m', 'pursīd', 'zan'), 7),
#  (('pursīd', 'zan', 'wināh'), 7),
#  (('zan', 'wināh', 'kerd'), 7),
#  (('kār', 'kerbag', 'kunēd'), 7),
#  (('yazdān', 'mēnōyān', 'gētīyān'), 7),
#  (('pad', 'nēk', 'ǰahišn'), 7),
#  (('pad', 'kār', 'andar'), 7),
#  (('zamīg', 'abar', 'rust'), 7),
#  (('rōz', 'Day', 'pad'), 7),
#  (('Day', 'pad', 'Mihr'), 7),
#  (('pad', 'zamīg', 'paydāg'), 7),
#  (('Spandarmad', 'Hordad', 'Amurdad'), 7),
#  (('dēn', 'mazdēsnān', 'pad'), 7),
#  (('druwand', 'Gannāg', 'Mēnōy'), 7),
#  (('Gannāg', 'Mēnōy', 'abāg'), 7),
#  (('xīr', 'gētīy', 'pad'), 7),
#  (('pad', 'dašn', 'dast'), 7),
#  (('abar', 'āyēd', 'pad'), 7),
#  (('āyēd', 'pad', 'rōz'), 7),
#  (('andar', 'ham', 'rōz'), 7),
#  (('pad', 'nērōg', 'wād'), 7),
#  (('Ganāg', 'Mēnōy', 'kerd'), 7),
#  (('sardag', 'andar', 'sardag'), 7),
#  (('pārag', 'pad', 'kust'), 7),
#  (('pad', 'sāl', 'abāz'), 7),
#  (('pad', 'tis', 'xwēš'), 7),
#  (('čiyōn', 'andar', 'gētīy'), 7),
#  (('andar', 'gumēxt', 'estēd'), 7),
#  (('rāy', 'dād', 'estēd'), 7),
#  (('pad', 'kust', 'abāxtar'), 7),
#  (('ayāb', 'bēšīd', 'bawēd'), 7),
#  (('bēwar', 'frawahr', 'ahlawān'), 7),
#  (('estēd', 'pad', 'kār'), 7),
#  (('frawahr', 'ahlawān', 'pad'), 7),
#  (('āsrōn', 'artēštār', 'wāstaryōš'), 7),
#  (('xwaršēd', 'pad', 'bālist'), 7),
#  (('Zardušt', 'Ohrmazd', 'pursīd'), 7),
#  (('harw', 'rōz', 'andar'), 7),
#  (('ayārīh', 'dādār', 'Ohrmazd'), 7),
#  (('frazendān', 'xwēš', 'rāy'), 7),
#  (('kas', 'pad', 'kāmag'), 7),
#  (('u-š', 'pad', 'gētīy'), 7),
#  (('u-š', 'pad', 'mēnōy'), 7),
#  (('pas', 'widerd', 'arzānīg'), 7),
#  (('xūb', 'frazām', 'bawād'), 7),
#  (('abēzag', 'weh-dēn', 'mazdēsnān'), 7),
#  (('ruwān', 'anōšag', 'bawād'), 7),
#  (('drōd', 'šādīh', 'rāmišnīh'), 7),
#  (('ruwān', 'ahlaw', 'bawād'), 7),
#  (('kunād', 'amāh', 'rāy'), 7),
#  (('mēnōy', 'ruwān', 'ahlaw'), 7),
#  (('gētīy', 'tan', 'dusraw'), 7),
#  (('mēnōy', 'ruwān', 'druwand'), 7),
#  (('kē-š', 'ruwān', 'grift'), 7),
#  (('bawād', 'pad', 'yazdān'), 7),
#  (('mēnōyān', 'gētīyān', 'mahist'), 7),
#  (('Ahrimen', 'druwand', 'dēwān'), 7),
#  (('frasāwandīh', 'xīr', 'gētīy'), 7),
#  (('pad', 'kāmag', 'Ohrmazd'), 7),
#  (('Ohrmazd', 'Zardušt', 'guft'), 7),
#  (('wināh', 'bun', 'šawēd'), 7),
#  (('druz', 'andar', 'tan'), 7),
#  (('kāmag', 'andar', 'axwān'), 7),
#  (('stūr', 'abāyēd', 'gumārdan'), 7),
#  (('pad', 'xwēšīh', 'abar'), 7),
#  (('ēdōn', 'čiyōn', 'pad'), 7),
#  (('pad', 'wizīr', 'dādwarān'), 7),
#  (('wināh', 'bawēd', 'ayāb'), 7),
#  (('ast', 'yazd', 'gāh'), 7),
#  (('yazd', 'gāh', 'dārēd'), 7),
#  (('dārēd', 'ast', 'druz'), 7),
#  (('ast', 'druz', 'rāh'), 7),
#  (('ōwōn', 'dāšt', 'Ahrimen'), 7),
#  (('kerbag', 'mizd', 'wināh'), 7),
#  (('pad', 'harw', 'kār'), 7),
#  (('pad', 'paywand', 'rawēd'), 7),
#  (('abar', 'dēn', 'mazdēst'), 7),
#  (('dēn', 'nigēz', 'weh-dēn'), 7),
#  (('padiš', 'nigēz', 'weh-dēn'), 7),
#  (('weh-dēn', 'pad', 'gōwišn'), 7),
#  (('dādār', 'u-š', 'dēn'), 7),
#  (('andar', 'mardōm', 'tan'), 7),
#  (('urwar', 'gōspand', 'mardōm'), 7),
#  (('awindišnīh', 'hunsand', 'bēšōmand'), 7),
#  (('wizīr', 'padiš', 'pad'), 7),
#  (('bawēd', 'u-š', 'pad'), 7),
#  (('ī-š', 'ast', 'pad'), 7),
#  (('pad', 'gōwišn', 'Ohrmazd'), 7),
#  (('pahlom', 'axwān', 'pad'), 7),
#  (('zamīg', 'gōspand', 'urwar'), 7),
#  (('dād', 'estēd', 'pad'), 7),
#  (('ēg-iš', 'pahlomīh', 'abar'), 7),
#  (('ī-šān', 'ǰud', 'ǰud'), 7),
#  (('ōwōn', 'dāšt', 'andar'), 7),
#  (('tis', 'rāy', 'kunēd'), 7),
#  (('pad', 'petīt', 'bawišn'), 7),
#  (('ēn-iz', 'ēdōn', 'pad'), 7),
#  (('andar', 'šahr', 'pad'), 7),
#  (('bōxt', 'ēraxt', 'paydāg'), 7),
#  (('paydāg', 'kunēd', 'pad'), 7),
#  (('pad', 'framān', 'Ohrmazd'), 7),
#  (('būd', 'ahlaw', 'Zarduxšt'), 7),
#  (('gēhān', 'astōmand', 'ahlāyīh'), 7),
#  (('Tūr', 'Urwāitāsang', 'Usixšān'), 7),
#  (('mēnōy', 'abzōnīg', 'dādār'), 7),
#  (('dādār', 'gēhān', 'astōmandān'), 7),
#  (('pahlom', 'ast', 'ābādīh'), 7),
#  (('ābādīh', 'ahlāyīh', 'pahlom'), 7),
#  (('ast', 'pahlom', 'ahlāyīh'), 7),
#  (('pahlom', 'ahlāyīh', 'ābādīh'), 7),
#  (('anīy', 'kas', 'pad'), 7),
#  (('ast', 'ābādīh', 'ahlāyīh'), 7),
#  (('pad', 'xšauuaš', 'måŋhō'), 7),
#  (('ēdōn', 'čiyōn', 'ka-š'), 7),
#  (('Ohrmazd', 'kerd', 'bawēd'), 7),
#  (('gōwišn', 'frāz', 'gōw'), 7),
#  (('kāmēd', 'būdan', 'gōw'), 7),
#  (('xwāstag', 'zan', 'frazend'), 7),
#  (('andar', 'abāyistan', 'gōwēd'), 7),
#  (('nibišt', 'gōwēd', 'xwāstag'), 7),
#  (('xwēšīh', 'man', 'mad'), 7),
#  (('čand', 'arz', '200'), 7),
#  (('pad', 'xwēšīh', 'dād'), 7),
#  (('dād', 'bawēd', 'gōwēd'), 7),
#  (('kunēd', 'kū-m', 'xwāstag'), 7),
#  (('anīy', 'kas', 'nēst'), 7),
#  (('dāštan', 'rāy', 'framān'), 7),
#  (('dūdag', 'pad', 'sālārīh'), 7),
#  (('xwāstag', 'ī-š', 'pad'), 7),
#  (('pad', 'stūrīh', 'dād'), 7),
#  (('harw', 'sāl', 'sāl'), 7),
#  (('Farrox', 'abāg', 'Mihrēn'), 7),
#  (('abāg', 'Mihrēn', 'paymān'), 7),
#  (('pad', 'margarzān', 'zēndān'), 7),
#  (('margarzān', 'zēndān', 'kerd'), 7),
#  (('pad', 'gōmēz', 'bār'), 7),
#  (('pad', 'baršnūm', 'abāyēd'), 7),
#  (('baršnūm', 'abāyēd', 'šustan'), 7),
#  (('Zardušt', 'ēn-iz', 'pursīd'), 7),
#  (('Ohrmazd', 'guft', 'kū-m'), 7),
#  (('pad', 'zamān', 'pādixšāy'), 7),
#  (('drōn', 'sar', 'kerd'), 7),
#  (('tahm', 'spāhbed', 'nēw'), 7),
#  (('šāhān-šāh', 'passandīd', 'u-š'), 7),
#  (('anōšag', 'bawēd', 'and'), 7),
#  (('framāyēd', 'pursīd', '-an'), 7),
#  (('zan', 'pad', 'zanīh'), 7),
#  (('kunēd', 'ēg-iš', 'wināh'), 7),
#  (('gōwēd', 'šāyēd', 'ayāb'), 7),
#  (('ēw-kardag', 'hamāg', 'rēman'), 7),
#  (('frāz', 'rawēd', 'u-š'), 7),
#  (('zan', 'čagar', 'pad'), 7),
#  (('pad', 'daštān', 'dārišn'), 7),
#  (('estēd', 'frōd', 'barēd'), 7),
#  (('pad', 'gāh', 'hāwan'), 7),
#  (('pad', 'dēn', 'framūd'), 7),
#  (('hamāg', 'kār', 'šāyēd'), 7),
#  (('Zardušt', 'ham-pursagīh', 'mad'), 7),
#  (('šāyēd', 'ayāb', 'šāyēd'), 7),
#  (('dādestān', 'čiyōn', 'ka-š'), 7),
#  (('pad', 'čāštag', 'Abargīg'), 7),
#  (('hazārag', 'sar', 'bawēd'), 7),
#  (('sar', 'bawēd', 'Spitāmān'), 7),
#  (('ysm-', 'TbD', 'sm-'), 7),
#  (('-x2', '-x1', '-x2'), 7),
#  (('wbš', 'YHByt', 'KON'), 7),
#  (('All', 'All', 'All'), 7),
#  (('ŠĀYIST', 'ŠĀYIST', 'ŠĀYIST'), 6),
#  (('andar', 'gēhān', 'rawāg'), 6),
#  (('man', 'dast', 'frāz'), 6),
#  (('frāz', 'mad', 'ham'), 6),
#  (('Ohrmazd', 'amahrspandān', 'pad'), 6),
#  (('Srōš-ahlaw', 'Ādur-yazd', 'gyāg'), 6),
#  (('aziš', 'hamē', 'waxšīd'), 6),
#  (('awēšān', 'ruwānān', 'hēnd'), 6),
#  (('Ohrmazd', 'amahrspandān', 'abārīg'), 6),
#  (('weh', 'dēn', 'māzdēsnān'), 6),
#  (('ruwān', 'zan-ēw', 'pad'), 6),
#  (('u-m', 'pursīd', 'tanān'), 6),
#  (('pad', 'gētīy', 'pad'), 6),
#  (('dīd', 'ruwān', 'zanān'), 6),
#  (('ruwān', 'zanān', 'kē-šān'), 6),
#  (('būd', 'hēnd', 'pad'), 6),
#  (('rist-āxēz', 'tan', 'pasēn'), 6),
#  (('pad', 'gētīy', 'andar'), 6),
#  (('u-m', 'pursīd', 'ruwānān'), 6),
#  (('u-šān', 'wināh', 'kerd'), 6),
#  (('mard', 'šahr', 'pad'), 6),
#  (('ōwōn', 'čiyōn', 'pad'), 6),
#  (('Ganāg', 'Mēnōy', 'pad'), 6),
#  (('3000', 'sāl', 'pad'), 6),
#  (('frāz', 'brēhēnīd', 'pad'), 6),
#  (('rōz', 'abar', 'pād'), 6),
#  (('abar', 'pād', 'rōz'), 6),
#  (('Mēx', 'mayān', 'āsmān'), 6),
#  (('xwaršēd', 'māh', 'stāragān'), 6),
#  (('harw', 'kas', 'xwēš'), 6),
#  (('xwēš', 'padīrift', 'u-š'), 6),
#  (('padīrift', 'u-š', 'dād'), 6),
#  (('u-š', 'dād', 'pad'), 6),
#  (('dēn', 'Ganāg', 'Mēnōy'), 6),
#  (('dād', 'Ganāg', 'Mēnōy'), 6),
#  (('čiyōn', 'pad', 'ēwēnag'), 6),
#  (('rōz', 'pad', 'ēwēnag'), 6),
#  (('frāz', 'rust', 'hēnd'), 6),
#  (('nar', 'mādag', 'pas'), 6),
#  (('aziš', 'būd', 'hēnd'), 6),
#  (('pad', 'kust', 'nēmrōz'), 6),
#  (('Frāxkerd', 'paywast', 'estēd'), 6),
#  (('pad', 'sar', 'kōf'), 6),
#  (('rāy', 'andar', 'abāyēd'), 6),
#  (('pad', 'zanīh', 'kerd'), 6),
#  (('xwah', 'pad', 'zanīh'), 6),
#  (('ēn-iz', 'gōwēd', 'pad'), 6),
#  (('abar', 'harw', 'kas'), 6),
#  (('ōwōn', 'čiyōn', 'andar'), 6),
#  (('and', 'bawēd', 'čand'), 6),
#  (('zrēy', 'Frāxkerd', 'pad'), 6),
#  (('harw', 'ǰār', 'andar'), 6),
#  (('paydāg', 'bawēd', 'pad'), 6),
#  (('tan', 'pasēn', 'kerdan'), 6),
#  (('ast', 'ahlāyīh', 'pahlom'), 6),
#  (('harw', 'kas', 'harw'), 6),
#  (('čiyōn', 'dēn', 'paydāg'), 6),
#  (('pad', 'kār', 'dādestān'), 6),
#  (('andar', 'ham', 'hazārag'), 6),
#  (('pad', 'Ērān', 'šahr'), 6),
#  (('bawēd', 'harw', 'kas'), 6),
#  (('ras', 'agar', 'awēšān'), 6),
#  (('nām', 'man', 'nibištār'), 6),
#  (('xwarrah', 'abēzag', 'weh-dēn'), 6),
#  (('ham', 'frāz', 'hišt'), 6),
#  (('xwēš', 'rāy', 'frazendān'), 6),
#  (('rāy', 'frazendān', 'xwēš'), 6),
#  (('Mihrābān', 'Spandyād', 'Mihrābān'), 6),
#  (('Spandyād', 'Mihrābān', 'Marzbān'), 6),
#  (('pad', 'ērīh', 'wehīh'), 6),
#  (('kāmag', 'xwēš', 'tuwān'), 6),
#  (('dēn-bandag', 'Marzbān', 'Frēdōn'), 6),
#  (('čiyōn', 'tan', 'kāmag'), 6),
#  (('xwānād', 'ayāb', 'hammōzād'), 6),
#  (('aēuuō', 'paṇtå', 'aṣ̌ahe'), 6),
#  (('paṇtå', 'aṣ̌ahe', 'vīspe'), 6),
#  (('ham', 'ēdōn', 'čiyōn'), 6),
#  (('pad', 'pahlom', 'axwān'), 6),
#  (('gētīy', 'tan', 'hu-sraw'), 6),
#  (('tis', 'grift', 'kē-š'), 6),
#  (('grift', 'kē-š', 'ruwān'), 6),
#  (('man', 'rāy', 'pad'), 6),
#  (('frāz', 'hišt', 'ham'), 6),
#  (('Ahrimen', 'dēwān', 'pad'), 6),
#  (('pad', 'nām', 'nērōg'), 6),
#  (('ǰud', 'pad', 'xwēš'), 6),
#  (('āstawānīh', 'abar', 'weh-dēn'), 6),
#  (('kerd', 'estēd', 'ayāb'), 6),
#  (('mizd', 'pāddāšn', 'dahēnd'), 6),
#  (('abar', 'rasēd', 'pad'), 6),
#  (('ayāb', 'čiyōn', 'bawēd'), 6),
#  (('bawēd', 'čiyōn', 'andar'), 6),
#  (('čiyōn', 'andar', 'dēn'), 6),
#  (('andar', 'āwām', 'āwām'), 6),
#  (('pad', 'zand', 'pad'), 6),
#  (('mard', 'ahlaw', 'pad'), 6),
#  (('xwāstag', 'pad', 'xwāstag-dārīh'), 6),
#  (('šāyēd', 'būd', 'pad'), 6),
#  (('mard', 'zan', 'pad'), 6),
#  (('pad', 'iθā', 'xwarēd'), 6),
#  (('čiyōn', 'abāyēd', 'dāštan'), 6),
#  (('iθā', 'aṣ̌əm', 'vohī'), 6),
#  (('ēn-iz', 'guft', 'estēd'), 6),
#  (('pad', 'rāh', 'widarg'), 6),
#  (('nēkīh', 'mad', 'estēd'), 6),
#  (('Ohrmazd', 'Spitāmān', 'Zardušt'), 6),
#  (('dahišn', 'dādār', 'Ohrmazd'), 6),
#  (('andar', 'yazdān', 'spāsdār'), 6),
#  (('bowandag', 'padiš', 'kerd'), 6),
#  (('abar', 'harw', 'tis'), 6),
#  (('pad', 'wattar', 'dēn'), 6),
#  (('pad', 'dādār', 'kām'), 6),
#  (('kēš', 'ī-šān', 'abar'), 6),
#  (('yazdīh', 'aziš', 'guft'), 6),
#  (('ǰud', 'ǰud', 'andar'), 6),
#  (('bawēd', 'nigēz', 'weh-dēn'), 6),
#  (('kām', 'dādār', 'u-š'), 6),
#  (('aziš', 'nigēz', 'weh-dēn'), 6),
#  (('yašt-frawahr', 'Spitāmān', 'Zarduxšt'), 6),
#  (('rādīh', 'rāstīh', 'spāsdārīh'), 6),
#  (('abar', 'Gannāg', 'Mēnōy'), 6),
#  (('hamē', 'andar', 'gēhān'), 6),
#  (('windišn', 'spāsdār', 'pad'), 6),
#  (('tuwān', 'abar', 'kerdan'), 6),
#  (('andar', 'dēn', 'pad'), 6),
#  (('menēnd', 'gōwēnd', 'kunēnd'), 6),
#  (('guftan', 'warzīdan', 'wināh'), 6),
#  (('mardōm', 'pad', 'tan'), 6),
#  (('āstawānīh', 'pad', 'dēn'), 6),
#  (('artēštārīh', 'wāstaryōšīh', 'hutuxšīh'), 6),
#  (('abārīg', 'gētīy', 'dahišnān'), 6),
#  (('wisp', 'mēnōyīg', 'gētīyīg'), 6),
#  (('andar', 'mardōmān', 'pad'), 6),
#  (('ēd-iz', 'rāy', 'mardōm'), 6),
#  (('kār', 'pad', 'kerbagīh'), 6),
#  (('hunar', 'andar', 'tan'), 6),
#  (('u-š', 'pad', 'menišn'), 6),
#  (('xwēš', 'rāy', 'kunēd'), 6),
#  (('mad', 'estēd', 'čiyōn'), 6),
#  (('abar', 'kerd', 'estēd'), 6),
#  (('pad', 'zāyišn', 'xandīd'), 6),
#  (('dast', 'pad', 'gōmēz'), 6),
#  (('ōwōn', 'dāšt', 'xēm'), 6),
#  (('dāšt', 'Ohrmazd', 'xwadāy'), 6),
#  (('bawēd', 'pad', 'dād'), 6),
#  (('dēn', 'ōwōn', 'paydāg'), 6),
#  (('ōwōn', 'dāšt', 'kas-iz'), 6),
#  (('dēn', 'pad', 'tan'), 6),
#  (('Abestāg', 'pad', 'čamišn'), 6),
#  (('nēkīh', 'ī-š', 'ast'), 6),
#  (('pad', 'kār', 'dārēd'), 6),
#  (('pad', 'Abestāg', 'Zand'), 6),
#  (('gāh', 'kerd', 'estēd'), 6),
#  (('ēdōn', 'šāyēd', 'kerdan'), 6),
#  (('xwēš', 'rāy', 'gōwēd'), 6),
#  (('pad', 'tis-iz', 'tis'), 6),
#  (('šawēd', 'ātaxš', 'niyāyišn'), 6),
#  (('pad', 'nāmčišt', 'paydāg'), 6),
#  (('dēn', 'āstawān', 'būdan'), 6),
#  (('ēn-iz', 'ēdōn', 'xwēš'), 6),
#  (('ēdōn', 'xwēš', 'tan'), 6),
#  (('guft', 'estēd', 'harw'), 6),
#  (('abar', 'abdīh', 'paydāgīhist'), 6),
#  (('abdīh', 'wasān', 'čiyōn'), 6),
#  (('wasān', 'čiyōn', 'dēn'), 6),
#  (('abzōnīg', 'dādār', 'gēhān'), 6),
#  (('gēhān', 'astōmandān', 'ahlaw'), 6),
#  (('gōwam', 'Spitāmān', 'Zarduxšt'), 6),
#  (('sidīgar', 'čahārom', 'panǰom'), 6),
#  (('haft', 'kišwar', 'xwadāy'), 6),
#  (('kunēnd', 'u-šān', 'pad'), 6),
#  (('pad', 'gyāg', 'pad'), 6),
#  (('tan', 'xwēš', 'sālār'), 6),
#  (('was', 'dādestān', 'andar'), 6),
#  (('abar', 'handarz', 'pad'), 6),
#  (('awiš', 'gumēxt', 'estēd'), 6),
#  (('ahlāyīh', 'pahlom', 'ābādīh'), 6),
#  (('Ohrmazd', 'Spitāmān', 'Zarduxšt'), 6),
#  (('andar', 'pahlom', 'axwān'), 6),
#  (('guft', 'ēdōn', 'čiyōn'), 6),
#  (('ēn-iz', 'kū-š', 'andar'), 6),
#  (('dād', 'hammōxt', 'bawēd'), 6),
#  (('bar', 'pad', 'xwēšīh'), 6),
#  (('ēd-iz', 'rāy', 'harw'), 6),
#  (('ā-š', 'guft', 'Ohrmazd'), 6),
#  (('Māmūn', 'Amīr', 'Mūminīn'), 6),
#  (('passandīd', 'pad', 'xūb'), 6),
#  (('harw', 'kas', 'ham-dādestān'), 6),
#  (('dādestān', 'sar', 'bawēd'), 6),
#  (('frazend', 'zāyēd', 'frazend'), 6),
#  (('pēšēmāl', 'gōwēd', 'xwāstag'), 6),
#  (('pad', 'dastwarīh', 'dāram'), 6),
#  (('Farrox', 'xwēš', 'būd'), 6),
#  (('anīy', 'gyāg-ēw', 'nibišt'), 6),
#  (('gōwēd', 'xwāstag', 'pad'), 6),
#  (('zan', 'pad', 'windišn'), 6),
#  (('xwēš', 'būd', 'rāy'), 6),
#  (('xwāstag', 'xwēšīh', 'man'), 6),
#  (('brād', 'abar', 'mānēd'), 6),
#  (('kunēd', 'xwāstag', 'pad'), 6),
#  (('rāy', 'framān', 'dād'), 6),
#  (('pad', 'grawīh', 'dāštan'), 6),
#  (('kū-m', 'xwāstag', 'pad'), 6),
#  (('pad', 'stūrīh', 'duxt'), 6),
#  (('mard', 'xwāstag', 'pad'), 6),
#  (('pid', 'xwāstag', 'pad'), 6),
#  (('sāl', 'pad', 'stūrīh'), 6),
#  (('frazend', 'zāyēd', 'xwāstag'), 6),
#  (('bahr', 'bahr', 'dād'), 6),
#  (('pad', 'zanīh', 'man'), 6),
#  (('abāg', 'guft', 'xwāstag'), 6),
#  (('pad', 'stūrīh', 'zan'), 6),
#  (('andarrōn', 'bērōn', 'hamāg'), 6),
#  (('Ohrmazd', 'amahrspandān', 'hamāg'), 6),
#  (('xwarišn', 'sāxtag', 'andar'), 6),
#  (('kē-š', 'ēdōn', 'guft'), 6),
#  (('menišnān', 'gōwišnān', 'kunišnān'), 6),
#  (('ēn-iz', 'dēn', 'paydāg'), 6),
#  (('Hōmāst', 'pad', 'zōhr'), 6),
#  (('pāy', 'estād', 'u-š'), 6),
#  (('ōzanēd', 'ā-š', 'tanābuhl'), 6),
#  (('ā-š', 'tanābuhl', 'kerbag'), 6),
#  (('yašt', 'meh', 'srūd-gāhān'), 6),
#  (('wāng', 'xar', 'wāng'), 6),
#  (('xar', 'wāng', 'šagr'), 6),
#  (('wāng', 'šagr', 'wāng'), 6),
#  (('šagr', 'wāng', 'uštar'), 6),
#  (('āxēzēd', 'abāz', 'kay-gāh'), 6),
#  (('abāz', 'kay-gāh', 'nišīnēd'), 6),
#  (('zarēr', 'ērān', 'spāhbed'), 6),
#  (('kerd', 'estēd', 'ēg-iš'), 6),
#  (('hamāg', 'xwaš', 'nēk'), 6),
#  (('homānāg', 'kunēm', 'čiyōn'), 6),
#  (('pad', 'ham', 'kār'), 6),
#  (('estēd', 'and', 'gyāg'), 6),
#  (('gyāg', 'tanābuhl', 'pad'), 6),
#  (('pādixšāy', 'ayāb', 'passox'), 6),
#  (('ǰumbēnēd', 'rēman', 'bawēd'), 6),
#  (('kunēd', 'šāyēd', 'ayāb'), 6),
#  (('nasāy', 'abar', 'rasēd'), 6),
#  (('abzōnīg', 'xwadāy', 'xwābar'), 6),
#  (('ān-iz', 'ēdōn', 'bawēd'), 6),
#  (('ka-š', 'ōbastan', 'bīm'), 6),
#  (('wahišt', 'rōšnīh', 'Ohrmazd'), 6),
#  (('māh', 'Ardwahišt', 'rōz'), 6),
#  (('estēd', 'čiyōn', 'ka-š'), 6),
#  (('čiyōn', 'abestāg', 'paydāg'), 6),
#  (('ham-pursagīh', 'mad', 'hēnd'), 6),
#  (('ēwēnag', 'paydāgēnīd', 'estēd'), 6),
#  (('ēg-iš', 'tanābuhl', 'bun'), 6),
#  (('tis-iz', 'handām', 'abāz'), 6),
#  (('abāz', 'pillagān', 'estēd'), 6),
#  (('ēg-iš', 'Nasuš', 'abar'), 6),
#  (('hōy', 'ham', 'ēdōn'), 6),
#  (('andar', 'škoft', 'āwām'), 6),
#  (('TbD', '-WNyt', 'TbD'), 6),
#  (('gnn-', 'TbD', 'yn-'), 6),
#  (('Tab', 'mlt-', 'Tab'), 6),
#  (('pyt-', 'TbD', 'pt-'), 6),
#  (('Tab', '-yyh', '-yš'), 6),
#  (('-x2', '-x2', '-x2'), 6),
#  (('YHByt', 'KON', 'wbš'), 6),
#  (('KON', 'wbš', 'YHByt'), 6),
#  (('DĒNKARD', 'DĒNKARD', 'DĒNKARD'), 5),
#  (('MĀDAYĀN', 'HAZĀR', 'DĀDESTĀN'), 5),
#  (('MĀDAYĀN', 'YŌIŠT', 'FRIYĀN'), 5),
#  (('gēhān', 'rawāg', 'kerd'), 5),
#  (('Gannāg', 'Mēnōy', 'druwand'), 5),
#  (('abar', 'pāy', 'estād'), 5),
#  (('didīgar', 'bār', 'pad'), 5),
#  (('Ādur-yazd', 'man', 'dast'), 5),
#  (('ī-š', 'pad', 'gētīy'), 5),
#  (('pad', 'gētīy', 'būd'), 5),
#  (('kerd', 'ham', 'pad'), 5),
#  (('pad', 'Činwad', 'puhl'), 5),
#  (('pādifrāh', 'gōnag', 'gōnag'), 5),
#  (('gyāg-ēw', 'frāz', 'mad'), 5),
#  (('Srōš-ahlaw', 'Ādur-yazd', 'man'), 5),
#  (('yazišn', 'yazdān', 'kerd'), 5),
#  (('u-m', 'abēr', 'burzišnīg'), 5),
#  (('abēr', 'burzišnīg', 'sahist'), 5),
#  (('duš-menišn', 'duš-gōwišn', 'duš-kunišn'), 5),
#  (('rāy', 'harw', 'kas'), 5),
#  (('Hordad', 'Amurdad', 'urwar'), 5),
#  (('pad', 'gētīy', 'šōy'), 5),
#  (('pursīd', 'tanān', 'wināh'), 5),
#  (('andar', 'dōšox', 'pad'), 5),
#  (('Ahrimen', 'dēwān', 'druzān'), 5),
#  (('zanān', 'kē-šān', 'pad'), 5),
#  (('gētīy', 'pad', 'mēnōy'), 5),
#  (('tanān', 'wināh', 'kerd'), 5),
#  (('tan', 'gyān', 'ruwān'), 5),
#  (('nasāy', 'pad', 'wināhgārīh'), 5),
#  (('hamē', 'šud', 'hēnd'), 5),
#  (('pad', 'ēwēnag', 'guft'), 5),
#  (('nēk', 'ǰahišn', 'xūb'), 5),
#  (('pad', 'harwisp-āgāhīh', 'dānist'), 5),
#  (('xwēš', 'kerdan', 'tuwān'), 5),
#  (('dēn', 'gōwēd', 'kū-š'), 5),
#  (('pad', 'bun-dahišn', 'dād'), 5),
#  (('šāyēd', 'kerdan', 'pad'), 5),
#  (('andar', 'aškomb', 'mādar'), 5),
#  (('brēhēnīd', 'pad', 'mard'), 5),
#  (('harw', 'tis', 'andar'), 5),
#  (('āb-ēw', 'srešk', 'pad'), 5),
#  (('pad', 'rōz', 'čiyōn'), 5),
#  (('rōz', 'čiyōn', 'rōz'), 5),
#  (('rōz', 'Ohrmazd', 'māh'), 5),
#  (('rōz', 'gāhānbār', 'u-š'), 5),
#  (('gāhānbār', 'u-š', 'nām'), 5),
#  (('dād', 'pad', 'rōz'), 5),
#  (('awiš', 'paywast', 'estēd'), 5),
#  (('Ohrmazd', 'xwadāy', 'pad'), 5),
#  (('u-š', 'dahišn', 'gētīy'), 5),
#  (('paywast', 'estēd', 'pad'), 5),
#  (('pad', 'dēn', 'Ganāg'), 5),
#  (('abar', 'āxēz', 'pid'), 5),
#  (('čiyōn', 'mēš', 'gurg'), 5),
#  (('weh', 'kār', 'kerbag'), 5),
#  (('kār', 'kerbag', 'kunēnd'), 5),
#  (('padiš', 'andar', 'dwārist'), 5),
#  (('pad', 'hōy', 'dast'), 5),
#  (('čiyōn', 'čašm-dīd', 'paydāg'), 5),
#  (('ānōh', 'pad', 'rōz'), 5),
#  ...]

# %%
df = pd.DataFrame([(x, y, z, c) for (x, y, z), c in pah_tri_phrases], columns=['tok1', 'tok2', 'tok3', 'count'])

# %%
df
# Out:
#              tok1        tok2         tok3  count
# 0           nigēz     weh-dēn          hād    355
# 1           u-šān       ēn-iz         ōwōn    331
# 2           ēn-iz        ōwōn         dāšt    328
# 3            ēdōn       bawēd        čiyōn     88
# 4           bawēd       ēd-iz          rāy     80
# 5          menišn      gōwišn       kunišn     73
# 6           gōwēd  Srōš-ahlaw    Ādur-yazd     73
# 7      Srōš-ahlaw   Ādur-yazd        ruwān     72
# 8         frazaft         pad         drōd     69
# 9             pad        drōd        šādīh     62
# 10          mēnōy        xrad       passox     62
# 11           xrad      passox         kerd     62
# 12         pursīd       dānāg        mēnōy     60
# 13          dānāg       mēnōy         xrad     60
# 14            ast        ēdōn        gōwēd     55
# 15          humad        hūxt      huwaršt     52
# 16            u-m         dīd        ruwān     52
# 17            tan       wināh         kerd     49
# 18          gōwēd         pad          dēn     45
# 19      Ādur-yazd       ruwān      druwand     44
# 20        xwāstag         pad       stūrīh     43
# 21            pad         tan        pasēn     42
# 22            u-m      pursīd          tan     41
# 23         pursīd         tan        wināh     41
# 24          čiyōn         man        dānam     41
# 25           drōd       šādīh       rāmišn     40
# 26          andar         ham          dar     40
# 27            u-š        guft      Ohrmazd     39
# 28           yašt        kerd        estēd     38
# 29           kerd       ruwān         ōwōn     35
# ...           ...         ...          ...    ...
# 23879        rep.         sup          pl-      2
# 23880         K24     drwyyt-          K24      2
# 23881         K24        f.st          K24      2
# 23882         K24         gy̤          yyh      2
# 23883         -yn        wār-          -WN      2
# 23884         K24        -WNš        -WNyh      2
# 23885         K24        -šhł       -šhlyD      2
# 23886         -WN       -WNyD          K24      2
# 23887      making        look         like      2
# 23888      broken         out          bol      2
# 23889        when         was       copied      2
# 23890        most         the         line      2
# 23891         the        line        empty      2
# 23892      Tištar        burd          pad      2
# 23893    barišnīh         mad          zōr      2
# 23894      supral         and         marg      2
# 23895       yyYtk        yhyn        yyYtk      2
# 23896        HLL-      -WNyt̨         HLL-      2
# 23897         duš    xwadāyīh          duš      2
# 23898    xwadāyīh         duš     xwadāyīh      2
# 23899       -ywtn         pyš          wtn      2
# 23900        2016        8:07         1469      2
# 23901        8:07        1469     February      2
# 23902        1469    February         2016      2
# 23903        2016        8:07     DĀDESTĀN      2
# 23904        8:07    DĀDESTĀN        DĒNĪG      2
# 23905        BOOK     CHAPTER      DĒNKARD      2
# 23906     CHAPTER     DĒNKARD         BOOK      2
# 23907        NASK     DĒNKARD         BOOK      2
# 23908        ZAND     FRAGARD  JUD-DĒW-DĀD      2
#
# [23909 rows x 4 columns]

# %%
df.to_csv('pahlavi_trigrams.csv')

# %%
type(pah_bi_freq)
# Out:
# nltk.probability.FreqDist

# %% [markdown]
# ### Conditional Frequency

# %%
# ConditionalFreqDist() takes a list of pairs.
# Generator variable uses itself up upon assignment, so need to recreate above

pah_bi2 = nltk.ngrams(pah_toks_clean, 2)
pah_bi2 = list(pah_bi2)

pah_cfd = nltk.ConditionalFreqDist(pah_bi2)

# %%
pah_cfd['draxt'].most_common(8)
# Out:
# [('xwānēnd', 6),
#  ('ī-š', 3),
#  ('nišīnēd', 3),
#  ('homānāg', 2),
#  ('dād', 2),
#  ('rust', 2),
#  ('mēwag', 2),
#  ('draxt', 2)]

# %% [markdown]
# ### Export Data

# %%
# for whatever reason you can't just use the concordance method on a string;
# you have to convert it to an NLTK Text type one way or another

pahlavi_corpus = nltk.Text(pah_toks_clean)

pahlavi_corpus.concordance('draxt')
# Out:
# Displaying 25 of 25 matches:
# R PT25 MĀH FRAWARDĪN RŌZ HORDAD PT26 DRAXT ASŪRĪG PT27 WIZĀRIŠN ČATRANG NIHIŠN
#  zamīg abar K20b_14v āmad hēnd čiyōn draxt homānāg tāg abar rēšag azēr rust u-š
# š hamē waxšīd 6d.6 nazdīk Wan Gōkarn draxt dād pad abāz-dārišnīh zarmān duš-pid
# .6* nazdīk Wan Harwisp-tōhmag Gōkarn draxt dād pad abāz-dārišnīh zarmān duš-pid
#  šud ast ruwān nūn-iz pad hangōšīdag draxt rust estēd kē-š bar ēwēnag mardōm 14
#  šud ast ruwān nūn-iz pad hangōšīdag draxt rust estād kē-š bar ēwēnag mardōm 14
#  harw xwarēd a-hōš bawēd u-š Gōkaran draxt xwānēnd čiyōn gōwēd hōm dūr-ōš u-š p
# r harw xwarēd a-hōš bawēd u-š Gōkarn draxt xwānēnd čiyōn gōwēd hōm dūr-ōš u-š p
#  ast 16.6 urwar and ēwēnag bawēd dār draxt mēwag ǰōrdāy gul sprahm tērag abzāra
# mag 16.6* urwar and ēwēnag bawēd dār draxt mēwag ǰōrdāg gul sprahm tārag ōzārag
# ār spēd-dār šamšār abārīg ēwēnag dār draxt xwānēnd 16.9 harw čē-š bar pad xwār-
# -bār mardōmān šāyēd šāyēd sālwār ast draxt xwānēnd TD2_61r/117 16.10* harw pad
# 10* harw pad rōzgār šāyēd sālwār ast draxt xwānēnd 16.11 harw pad pyhw lwc šāyē
# TD1_50r asmān zamīg arzēd ǰud Gōkarn draxt ī-š rist padiš āxēzēnd 17a.21* urwar
# wisp urwar Xwanīrah arzēd ǰud Gōkard draxt ī-š rist padiš wirāyēnd 17a.31 kōfān
# ndBdh XVII 24.0* ABAR ČIYŌNĪH GŌKARN DRAXT XWĀNĒND 24a.1 gōwēd pad dēn Hōm spēd
#  24a.1 gōwēd pad dēn Hōm spēd Gōkarn draxt xwānēd andar zrēy Frāxkerd pad zufr
# 4a.1* gōwēd pad dēn rōz naxust Gogrv draxt xwānēnd andar zrēy Frāxkerd pad zafr
# yazdān wehān Rōstahm Dād-Ohrmazd nōg draxt farrox būm Spahān Rōd-dašt rōdestāg
# r D7_221 dārēnd T60_64v pad nām yazd draxt kārēnd p̄l -išn xwarēnd abārīg gētīy
# nd drūnēnd pad-iš zīyēnd anīy drūnāy draxt K43_175v urwar nēst 61.22 u-š zargōn
# hmag 61.38 hamē abar āxēzēd 1000 tāg draxt rōyēd 61.39 nišīnēd 1000 tāg škennēd
# bawēd 3.20 pursīd 3.20.1 pursīd abar draxt sar azēr pad draxt bun pādyābīh ast
# .20.1 pursīd abar draxt sar azēr pad draxt bun pādyābīh ast nasāy mardōm ayāb s
# ānag nasāy pādyābīh pad ǰud abar šud draxt bīm pad rēmanīh ast-iz margarzānīh p
