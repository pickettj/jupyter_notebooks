# %%
import numpy as np
import pandas as pd

from pandas import DataFrame, Series

# %%
# Set some pandas options
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ### Reading in Data

# %%
skj = pd.read_csv('data/skj.csv', names=['script', \
                                                'sk_tslit', 'sk_def'])

# %%
mkz = pd.read_csv('data/mknz_codes.csv', names=['uid', 'script'])

# %% [markdown]
# ### Merging Data

# %%
merge = pd.merge(skj, mkz, on = "Loc_ID")

# %%
heat_merge
# Out:
#      Loc_ID      Lat_Y     Long_X       Nickname  Entry_UID
# 0         3  39.776910  64.413150        Bukhara       9001
# 1         3  39.776910  64.413150        Bukhara       9001
# 2         3  39.776910  64.413150        Bukhara       9001
# 3         3  39.776910  64.413150        Bukhara       9001
# 4         3  39.776910  64.413150        Bukhara       9001
# 5         3  39.776910  64.413150        Bukhara       9001
# 6         3  39.776910  64.413150        Bukhara       9001
# 7         3  39.776910  64.413150        Bukhara       9001
# 8         3  39.776910  64.413150        Bukhara       9001
# 9         3  39.776910  64.413150        Bukhara       9001
# 10        3  39.776910  64.413150        Bukhara       9001
# 11        3  39.776910  64.413150        Bukhara       9001
# 12        3  39.776910  64.413150        Bukhara       9001
# 13        3  39.776910  64.413150        Bukhara       9001
# 14        3  39.776910  64.413150        Bukhara       9001
# ...

# %% [markdown]
# ### Exporting Data

# %%
#Multiple full-names on separate lines gets messed up in export.
del heat_merge['Fullname']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fullname'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-6a817d42f634> in <module>()
# ...

# %%
heat_merge.to_csv("exported_data/vienna_heat.csv")
