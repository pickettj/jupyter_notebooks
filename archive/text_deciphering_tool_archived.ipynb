# %% [markdown]
# # Text Deciphering Tool

# %%
import pickle, re, nltk

# %%
import numpy as np
import pandas as pd

from pandas import DataFrame, Series

# %% [markdown]
# Sister files:
# - Pickled corpora cleaned in text_cleaning_tokenizing
# - Corpora stats in corpora_statistics

# %% [markdown]
# ## I. Importing Corpora

# %% [markdown]
# Corpora:
# - (1) indo_toks = Indian historical manuscripts edited by others
# - (2) indo_toks_man = Indian historical manuscripts transcribed by me
# - (3) edited_toks = Transoxania historical manuscripts edited by others
# - (4) notes_toks = Transoxania historical manuscripts edited by me
# - (5) pers_lit_toks = Full Persian literary corpus (from Roshan)
# - (6) markdown_toks = Document transcriptions at MarkDown stage
# - (7) xml_toks = Document trasncriptoins at XML stage

# %%
with open("pickled_refined_data/corpora.pkl", "rb") as f:
    edited_toks, indo_toks, indo_toks_man, notes_toks, markdown_toks, xml_toks = pickle.load(f)

# %%
#markdown_toks.keys()

# %% [markdown]
# Sub-Corpuses:
# - (a) Indic Persian Mansucripts: corpus (1) + manuscript notes (2)
# - (b) Transoxania Manuscripts: corpus (3) + manuscript notes (4)
# - (c) Persian literature (5)
# - (d) Documents (right now all together, regardless of location): markdown (6) + xml (7)

# %% [markdown]
# Combined Corpora:
# - (i) History: a + b
# - (ii) Literature: c
# - (iii) Documents: d
#
# Meta Corpus: i+ii+iii

# %%
with open("pickled_refined_data/meta_corpora.pkl", "rb") as f:
    india_man_toks, trans_man_toks, doc_corpus_toks, hist_corpus_toks, combined_corpus_toks = pickle.load(f)

# %%
#combined_corpus_toks.keys()

# %% [markdown]
# ## II. Importing Raw Tokens
# I.e. tokens without parent text designation, i.e. format necessary for many NLTK routines.

# %%
with open("pickled_refined_data/raw_tokens.pkl", "rb") as f:
    doc_toks, hist_toks, lit_toks, combined_toks = pickle.load(f)

# %% [markdown]
# ## III. Importing Datasets

# %% [markdown]
# - Von Melzer Persian Lexicon
# - Glossary
# - Place Names

# %%
# Von Melzer
meltzer = pd.read_csv("data_master/von_melzer.csv")

# %%
#meltzer["Transkription"].sample(5)
#meltzer.head()

# %%
# Locations
locations = pd.read_csv('data/locations.csv', names=['UID', 'Ar_Names', \
                                                'Lat_Name', 'Nickname', 'Type'])

# Social Roles

# Glossary

glossary = pd.read_csv('data/glossary.csv', names=['UID', 'Term', \
                                                'Eng_Term', 'Translation', 'Transliteration', 'Scope', 'Tags'])

# %% [markdown]
# ___
# ___

# %% [markdown]
# # Basic Search

# %% [markdown]
# Regex reminders:
# - Just the word itself: `^مال$`

# %%
search_term = re.compile(r"..احب")

# %% [markdown]
# ### Von Melzer Persion Dictionary

# %%
melz_query_mask = meltzer["Präs.-Stamm"].str.contains(search_term, na=False)
melz_query = meltzer[melz_query_mask]
melz_query
# Out:
#          UID Volume  Unnamed: 2  Persisch                      Präs.-Stamm  \
# 2241    2242      I        2241      2242               ‫اﺟلۀ صاحب منصبان‬
# 2381    2382      I        2381      2382             (Pl. ‫احبوش )احابیش‬
# 9570    9571      I        9570      9571                        ‫آن صاحب‬
# 18128  18129      I       18128      6640                       ‫بی صاحبی‬
# 25903  25904     II        7119      2751                          ‫تصاحب‬
# 25904  25905     II        7120      2752                     ‫تصاحب کردن‬
# 25905  25906     II        7121      2753                     ‫تصاحب کردن‬
# 33354  33355     II       14570      1318                      ‫حکیم صاحب‬
# 34012  34013     II       15228       183                ‫خاقان صاحب قران‬
# 38057  38058    III         464       166            5   ‫درﺟۀ صاحب منصفی‬
# 43685  43686    III        6092         2              ‫سادات صاحب سعادات‬
# 44851  44852    III        7258      1168                ‫سلطان صاحب قران‬
# 48487  48488    III       10894        17                           ‫صاحب‬
# 48488  48489    III       10895        18                           ‫صاحب‬
# 48489  48490    III       10896        19                           ‫صاحب‬
# 48490  48491    III       10897        20                           ‫صاحب‬
# 48491  48492    III       10898        21                      ‫صاحب آباد‬
# 48492  48493    III       10899        22                      ‫صاحب آباد‬
# 48493  48494    III       10900        23                   ‫صاحب اتومبیل‬
# 48494  48495    III       10901        24                    ‫صاحب اختصاص‬
# 48495  48496    III       10902        25                    ‫صاحب اختیار‬
# 48496  48497    III       10903        26                    ‫صاحب اختیار‬
# 48497  48498    III       10904        27          ‫صاحب اختیار امور بودن‬
# 48498  48499    III       10905        28                     ‫صاحب اخلاق‬
# 48499  48500    III       10906        29               ‫صاحب اخلاق ستوده‬
# 48500  48501    III       10907        30                ‫صاحب ارادۀ متین‬
# 48501  48502    III       10908        31                      ‫صاحب اطاق‬
# 48502  48503    III       10909        32               ‫صاحب اقتدار بودن‬
# 48503  48504    III       10910        33                   ‫صاحب الاخلاص‬
# 48504  48505    III       10911        34                     ‫صاحب الجیش‬
# ...      ...    ...         ...       ...                              ...
# 48623  48624    III       11030       153                       ‫صاحب نظر‬
# 48624  48625    III       11031       154                       ‫صاحب نظر‬
# 48625  48626    III       11032       155                      ‫صاحب نظری‬
# 48626  48627    III       11033       156                 ‫صاحب نظری کردن‬
# 48627  48628    III       11034       157                       ‫صاحب هنر‬
# 48628  48629    III       11035       158                       ‫صاحب هوش‬
# 48629  48630    III       11036       159               ‫صاحب هوش و ذکاوت‬
# 48630  48631    III       11037       160                     ‫صاحب یخدان‬
# 48631  48632    III       11038       161                      ‫صاحب یقین‬
# 48632  48633    III       11039       162                   ‫صاحبان اخلاق‬
# 48633  48634    III       11040       163                      ‫صاحبقرانی‬
# 48634  48635    III       11041       164                          ‫صاحبه‬
# 48635  48636    III       11042       165                     ‫صاحبۀ اجنه‬
# 48636  48637    III       11043       166                   ‫صاحبة الجمال‬
# 48637  48638    III       11044       167                         ‫صاحبیه‬
# 48638  48639    III       11045       168                     ‫صاحب… بودن‬
# 48639  48640    III       11046       169                     ‫صاحب… بودن‬
# 48874  48875    III       11281       404  ‫صحبت‬/‫صحبة الاحباب‬ ‫الاحباب‬
# 56737  56738    III       19144       271                 ‫کلاه صاحب مرده‬
# 64614  64615     IV        7587      4309                          ‫مصاحب‬
# 64615  64616     IV        7588      4310                          ‫مصاحب‬
# 64616  64617     IV        7589      4311                          ‫مصاحب‬
# 64617  64618     IV        7590      4312                         ‫مصاحبت‬
# 64618  64619     IV        7591      4313                         ‫مصاحبت‬
# 64619  64620     IV        7592      4314              (‫مصاحبت داشتن )با‬
# 64620  64621     IV        7593      4315               (‫مصاحبت کردن )با‬
# 64621  64622     IV        7594      4316                    (‫مصاحبه )با‬
# 64622  64623     IV        7595      4317                    (‫مصاحبه )با‬
# 64623  64624     IV        7596      4318                    (‫مصاحبه )با‬
# 64624  64625     IV        7597      4319               (‫مصاحبه کردن )با‬
#
#                          Transkription  \
# 2241      aǧelle⁺-je sāheb⁺ mansab⁺-ān
# 2381               ohbūš⁺ (Pl. ahābīš)
# 9570                         ān sāheb⁺
# 18128                       bī-sāheb⁺ī
# 25903        tasāhob⁺                A
# 25904        tasāhob⁺ kardan (+Akk.) b
# 25905        tasāhob⁺ kardan (+Akk.) i
# 33354                    hakīm⁺ sāheb⁺
# 34012          ḫāqān⁺⁺-e sāheb⁺-qerān⁺
# 38057      daraǧe⁺-je sāheb⁺- mansaf⁺ī
# 43685                               sā
# 44851          soltān⁺-e sāheb⁺-qerān⁺
# 48487                           sāheb⁺
# 48488                           sāheb⁺
# 48489                           sāheb⁺
# 48490                           sāheb⁺
# 48491                      sāheb⁺-ābād
# 48492                      sāheb⁺-ābād
# 48493                sāheb⁺-e otōmobīl
# 48494                sāheb⁺-e eḫtesās⁺
# 48495                  sāheb⁺-eḫtijār⁺
# 48496                  sāheb⁺-eḫtijār⁺
# 48497  sāheb⁺-e eḫtejār⁺-e omūr⁺ būdan
# 48498                  sāheb⁺-e aḫlāq⁺
# 48499       sāheb-⁺e aḫlāq⁺-e sotūde c
# 48500        sāheb⁺-e erāde⁺-je matīn⁺
# 48501                    sāheb⁺-otāq⁺⁺
# 48502       sāheb⁺-e eqtedār⁺ būdan di
# 48503                 sāhebo⁺-l-eḫlās⁺
# 48504                  sāhebo⁺-l-ǧejš⁺
# ...                                ...
# 48623                    sāheb⁺-nazar⁺
# 48624                    sāheb⁺-nazar⁺
# 48625                   sāheb⁺-nazar⁺ī
# 48626            sāheb⁺-nazar⁺ī kardan
# 48627                     sāheb⁺-honar
# 48628                     sāheb⁺-e hūš
# 48629          sāheb⁺-e hūš o zakāwat⁺
# 48630                 sāheb⁺-e jaḫ-dān
# 48631                  sāheb⁺-e jaqīn⁺
# 48632                sāheb⁺ān-e aḫlāq⁺
# 48633                   sāheb⁺-qerān⁺ī
# 48634                          sāhebe⁺
# 48635               sāhebe⁺-je aǧenne⁺
# 48636               sāhebato⁺-l-ǧamāl⁺
# 48637                       sāhebijje⁺
# 48638                  sāheb⁺-e… būdan
# 48639                  sāheb⁺-e… būdan
# 48874                              NaN
# 56737             kolāh-e sāheb⁺-morde
# 64614                               mo
# 64615                               mo
# 64616                               mo
# 64617                               mo
# 64618                               mo
# 64619                               mo
# 64620                               mo
# 64621                               mo
# 64622                               mo
# 64623                               mo
# 64624            mosāhabe⁺ kardan (bā)
#
#                                                  Deutsch  \
# 2241                          die höchsten der Offiziere
# 2381                                          Horde (f.)
# 9570                jener Herr (Briefanrede an Europäer)
# 18128                               Herrenlosigkeit (f.)
# 25903                                                nei
# 25904                                                ese
# 25905                                                n B
# 33354                                       Herr Doktor!
# 34012  der Großherr mit der günstigen Stern- stellung...
# 38057  Rangabzeichen der Offiziere              [rect...
# 43685                             dāt⁺-e sāheb⁺-saʾādāt⁺
# 44851  der Herrscher, der durch die Stern- stellung b...
# 48487                                      Besitzer (m.)
# 48488                                    Eigentümer (m.)
# 48489                                          Herr (m.)
# 48490                                     Verfasser (m.)
# 48491                       (ein Stadtviertel in Tabris)
# 48492  (Name eines Gartens in Tabris, 9.-15. Jahrhund...
# 48493                            Kraftwagenbesitzer (m.)
# 48494                                     Fachmann (m.)*
# 48495                                             (Name)
# 48496                                         unabhängig
# 48497           nach Belieben schalten und walten können
# 48498                               höflich; wohlerzogen
# 48499                                       haraktervoll
# 48500                                       willensstark
# 48501                     Zimmergast (m.) (der Herberge)
# 48502                                      e Macht haben
# 48503                                             lauter
# 48504                          Herr (m.) der Heeresmacht
# ...                                                  ...
# 48623                               Scharfsichtiger (m.)
# 48624                                         verständig
# 48625           Einsichtigkeit (f.); Verständigkeit (f.)
# 48626                                    einsichtig sein
# 48627                                     Tüchtiger (m.)
# 48628                 Verständiger (m.); Besonnener (m.)
# 48629          Vernünftiger (m.) und Scharfsinniger (m.)
# 48630                                   Koffer besitzend
# 48631                                             sicher
# 48632                                Leute von Charakter
# 48633               Stehen unter günstiger Sternstellung
# 48634                                    Besitzerin (f.)
# 48635                           Geisterbeschwörerin (f.)
# 48636                                        schöne Frau
# 48637                         freundschaftliche Gedichte
# 48638                                     besitzen (was)
# 48639                                        haben (was)
# 48874                                  sohbato⁺-l-ahbāb⁺
# 56737                  die Mütze, deren Besitzer tot ist
# 64614                                             sāheb⁺
# 64615                                             sāheb⁺
# 64616                                             sāheb⁺
# 64617                                       sāhabat⁺(-e)
# 64618                                           sāhabat⁺
# 64619                               sāhabat⁺ dāštan (bā)
# 64620                               sāhabat⁺ kardan (bā)
# 64621                                       sāhabe⁺ (bā)
# 64622                                       sāhabe⁺ (bā)
# 64623                                 sāhabe⁺ (bā) (mit)
# 64624                           umgehen; verkehren (mit)
#
#                                     Bemerkung  \
# 2241                                      NaN
# 2381                                      NaN
# 9570                                      NaN
# 18128                                     NaN
# 25903                              gnung (f.)
# 25904                                    tzen
# 25905             esitz nehmen; sich aneignen
# 33354                                     NaN
# 34012                                     NaN
# 38057                                       ﻲ
# 43685               die glückseligen Sejjiden
# 44851                                     NaN
# 48487                                     NaN
# 48488                                     NaN
# 48489                                     NaN
# 48490                                     NaN
# 48491                                     NaN
# 48492                                     NaN
# 48493                                     NaN
# 48494                                     NaN
# 48495                                     NaN
# 48496                                     NaN
# 48497                                     NaN
# 48498                                     NaN
# 48499                                     NaN
# 48500                                     NaN
# 48501                                     NaN
# 48502                                     NaN
# 48503                                     NaN
# 48504                                     NaN
# ...                                       ...
# 48623                                     NaN
# 48624                                     NaN
# 48625                                     NaN
# 48626                                     NaN
# 48627                                     NaN
# 48628                                     NaN
# 48629                                     NaN
# 48630                                     NaN
# 48631                                     NaN
# 48632                                     NaN
# 48633                                     NaN
# 48634                                     NaN
# 48635                                     NaN
# 48636                                     NaN
# 48637                                     NaN
# 48638                                     NaN
# 48639                                     NaN
# 48874         Unterhaltung (f.) der Liebenden
# 56737                                     NaN
# 64614                          Begleiter (m.)
# 64615                           Gefährte (m.)
# 64616                     Gesellschafter (m.)
# 64617         Umgang (m.); Verkehr (m.) (mit)
# 64618     Unterredung (f.); Unterhaltung (f.)
# 64619                verkehren; umgehen (mit)
# 64620                verkehren; umgehen (mit)
# 64621         Umgang (m.); Verkehr (m.) (mit)
# 64622  Unterhaltung (f.); Gespräch (n.) (mit)
# 64623      Unterredung (f.); Besprechung (f.)
# 64624                                     NaN
#
#                                           Quellenangaben
# 2241                                      Kāva I/11:6/3b
# 2381                                                 NaN
# 9570                                       Beck 1915:221
# 18128                    Ibrāhīm Baik (Siyāḥatnāma 26/3)
# 25903                                Šaibānī 1314:I 76/8
# 25904                                       Īrān 6015/3a
# 25905  Ramażānī 1315:21/21, 246/11, Šaibānī 1314:I 34...
# 33354                   Qaraǧadaġī (Mūsī Žūrdān 21) 1197
# 34012             Qulī-Ḫān (Sifāratnāma 14/6, 18, 20/19)
# 38057                                ‬Īrānšahr I 21/20f.
# 43685         Ḫwāndamīr (Geschichte Tabaristans 22/14f.)
# 44851               Salmān Sāvuǧī (Erdmann 1861a:759/20)
# 48487  Saʿdī (Qaṣāʾid-i fārsī 31/2), 1. Mose 4/20, Sa...
# 48488  Qulī-Ḫān (Sifāratnāma 6/10, 10/14), Hidāyat (I...
# 48489  Anvarī (Qaṣāʾid 23/16), Saʿdī (Qaṣāʾid-i fārsī...
# 48490  ŠL I 3/20, FR I 24/26, MF I 65/18, 66/8, Īrānī...
# 48491                  Iskandar Munšī (Erdmann 1860:720)
# 48492                                        EdI IV 636b
# 48493                                       Īrān 6073/4c
# 48494                                    Īrānšahr I 71/6
# 48495                                 Kašf-i talbīs 62/4
# 48496                                    Daulatšāh 43/19
# 48497                                       Beck 1915:98
# 48498                                      Beck 1914:195
# 48499                                 Īrānšahr II 618/22
# 48500                                       Smiles 11/31
# 48501                                   Morier 1905:36/6
# 48502                                          Bāb 27/10
# 48503                             Saʿdī (Jensen 1931:57)
# 48504           Ḫwāndamīr (Geschichte Tabaristans 19/11)
# ...                                                  ...
# 48623                                     Jensen 1931:51
# 48624                                       Īrān 6058/1c
# 48625                                                NaN
# 48626                                               Rūmī
# 48627                              Saʿdī (Gulistān 7/19)
# 48628                 Saʿdī (Gulistān 57/5), Sharq 118/8
# 48629                                  Īrānšahr I 127/14
# 48630                                  Morier 1905:192/4
# 48631                                          FA 49/19a
# 48632                                        Smiles 4/21
# 48633                                          MF I II/4
# 48634                                Wahrmund 1898:I 143
# 48635                                   1. Chronik 10/13
# 48636                                Wahrmund 1898:I 143
# 48637                                   Pertsch 1859:197
# 48638                                      Beck 1914:167
# 48639                                      Smiles 140/19
# 48874                                Saʿdī (Marāī 10/3)
# 56737                                   Morier 1905:19/8
# 64614                                    Haas 1876:635/5
# 64615      Īrān 6053/1c, Ibrāhīm Baik (Siyāḥatnāma 21/2)
# 64616                     Ibrāhīm Baik (Siyāḥatnāma 21/2
# 64617            Saʿdī (Gulistān 48/1), Morier 1905:70/9
# 64618                                       BQ I 121/16a
# 64619                                          FA 11/10b
# 64620                            Šarq 13/13, Smiles 45/8
# 64621                           Šarq 681/3, Smiles 47/11
# 64622                                       Īrān 4639/2b
# 64623  Īrān 5828/2e, 6011/2c, 6034/3d f., 6073/3a, Sm...
# 64624                                        Smiles 6/16
#
# [178 rows x 9 columns]

# %% [markdown]
# ### Database Terms

# %% [markdown]
# #### (a) Technical Lexicon

# %%
glos_query_mask = glossary["Term"].str.contains(search_term, na=False)
glos_query = glossary[glos_query_mask]
glos_query
# Out:
# Empty DataFrame
# Columns: [UID, Term, Eng_Term, Translation, Transliteration, Scope, Tags]
# Index: []

# %% [markdown]
# #### (b) Social Roles

# %% [markdown]
# #### (c) Place Names

# %%
loc_query_mask = locations["Ar_Names"].str.contains(search_term, na=False)
loc_query = locations[loc_query_mask]
loc_query
# Out:
# Empty DataFrame
# Columns: [UID, Ar_Names, Lat_Name, Nickname, Type]
# Index: []

# %% [markdown]
# ### Corpus Tokens

# %%
combo_freq = nltk.FreqDist(combined_toks)
toks = [x for x in combo_freq if re.match(search_term, x)]
toks[:5]
# Out:
# ['بصاحب', 'مصاحبت', 'مراحب', 'مصاحب', 'بصاحبقران']

# %% [markdown]
# ### Keyword in Context

# %%
search_term = re.compile(r"عیدین")

# %%
trans_corpus = nltk.Text(combined_toks)

# %%
conc0 = sum([trans_corpus.concordance_list(x) for x in toks], [])
conc1 = [c.line for c in conc0]
print('\n'.join(conc1))
# Out:
# بق دستور سابق عبد الرحیم خانخانان را بصاحب صوبگی خاندیس و برار و دکن سرافرازی د
# ید ضبط درآورده داراب خان را قسم داده بصاحب سوبگی بنگاله سرافراز فرمودند و زن و
# عار ازو انتزاع نموده خلعت خلافت والا بصاحب دولتی دیگر بپوشانند و افسر سروری بر
#  سببی باو داشتند منزلتهای والا یافته بصاحب صوبگی صوبه های کلان لوای استقلال برا
# و عواطف پادشاهانه که بر همه سرافرازی بصاحب صوبگی گجرات بود مشمول گردید و مامور
# ش مخمل زربفت مرحمت نموده لشکر خان را بصاحب صوبگی کابل و مرحمت خلعت خاصه سرافراز
# خان خانخانان از تغییر خان جهان لودهی بصاحب صوبگی دکن و خاندیس و برار و سرداری ا
# سپ از طویله خاصه سر مباهات برافراخته بصاحب صوبگی دهلی سرافراز شده دستوری یافت م
#  بفوجداری پرگنات اکبرآباد و وزیر خان بصاحب صوبگی پنجاب سرافراز گردیدند و باعث ا
# ر بحراست آباد از تغییر قلیچ خان و او بصاحب صوبگی ملتان از تغییر نجابت خان سعادت
# ند باقر خان بعد از تغییر صوبه اودیسه بصاحب صوبگی ولایت گجرات از تغییر اسلام خان
# ب پنج هزاری ذات و سوار سربلندی یافته بصاحب صوبگی پنجاب علم عزت برافراخت حکیم دا
# ودند این نزهتکده بدیع آیین که بالفعل بصاحب آباد موسوم است از جمیع جهات خوبی در
# ده بود در سر سواری بدیدن اکتفا نموده بصاحب آباد معاودت فرمودند این مکان نزهت آف
# ر باراده سیر و گلگشت اچ ول که بالفعل بصاحب آباد موسوم است کوچ فرموده بعد از قطع
# واسپه سه اسپه و دو برآوردی مقرر گشته بصاحب صوبگی کابل از تغییر سعید خان سرافراز
# بت و سیار چرخ هشتم بر بساط هفت اقلیم بصاحب نظران نموده و روشنگر سرعت از آیینه ن
# ر سال هفدهم از تغییر سعید خان ظفرجنگ بصاحب صوبگی پنجاب چهره بلندرتبگی افروخت و
# و یکم از آنجا تغییر شده بحضور رسید و بصاحب صوبگی لاهور اختصاص گرفت و پس از آن ف
# داقبال بود بعقد ازدواج درآورده موسوم بصاحب بیگم نمود و بدین انتساب جدید پسران ا
# ه معاودت کرد و در اواخر عهد جهانگیری بصاحب صوبگی مالوه بلندپایه گردید و پس از ا
# ن جهان لودی عزیمت دکن نمود مهابت خان بصاحب صوبگی دار الملک دهلی نامزد گردید و د
# کار سورته مباهی گردید در سال پانزدهم بصاحب صوبگی گجرات از تغییر اعظم خان اختصاص
# ها در صوبه کابل بسر برد و در سال نهم بصاحب صوبگی کشمیر اختصاص گرفت و در سال سیز
# انتقال حسن علی خان بهادر عالمگیرشاهی بصاحب صوبگی برار مورد نوازش گشت و پس از فت
# لس قاضی محسن پسر قاضی معزرا که نسبت مصاحبت با طالب خان داشت و در آنوقت آنجا حا
#  و فصاحت بیان و ابواب مجالست و آداب مصاحبت ملوک خصوص سنجیدگی حرکات و سکنات و م
# هرآیینه بدستوری خرد ادب آیین دست از مصاحبت دستور دانش منش خویش بزرجمهر دانا شس
#  ایران آمده با نواب آصف صفات بعنوان مصاحبت بسر می برد و بعد از رحلت آن والامکا
# نیجه می گفتند در خدمت جنت مکانی طرف مصاحبت نیز پیدا کرد روزی پادشاه آب خاصه طل
# درزاده شمس الدین محمد خوافی را بعلت مصاحبت و خصوصیت آصف خان ازهم گذرانیده بود
# س از آن به بخشیگری دوم و مزید قرب و مصاحبت لوای برتری می افراخت و در سرآغاز جل
# یند چندان کسب علم نکرده بود از کثرت مصاحبت با اهل کمال علم مجلس و تقریر خوب به
# ری که در آن ولایت رسید میررا بقرب و مصاحبت خویش برنواخته باعزاز و احترام تلقی
#  دانشهای گوناگون بود پیوست و بعنوان مصاحبت بسر می برد پس از ارتحال آن امیر ستو
# مشمول عواطف ساخته بتقرر جاگیر و قرب مصاحبت خود خرسند گردانید سال هزار و یکصد و
# ر فرصتی غیر از مط لب حج ام که رابطه مصاحبت داشت کسی نماند دریافته آمد که عبرت
# صافی همان تواند بود و مجالست صوری و مصاحبت ظاهری را بدل عدیم البدل توان شمرد و
#  آشیانی سعادت روشناسی اندوخته بدولت مصاحبت امتیاز یافت و بمنصب هفتصدی و خطاب د
# بمنصب دوهزاری اختصاص یافته مگر غرور مصاحبت و خصوصیتی که بپادشاه داشت مقتضی این
# بدو تفویض یافت با آنکه با سردار طرف مصاحبت داشت بخست و نکبت زندگی بسر می برد و
# وازش گردیده بتدریج درجه پیمای قرب و مصاحبت گشت و قسمی پوست کشی شیخ عبد النبی ص
# فیس بسرکار پادشاهی ضبط شد پیش آمد و مصاحبت شیخ در پیشگاه خلافت بعنوان علم و کم
# خفیف تر ساخته در عرصه اعتبار بقرب و مصاحبت روزافزون پادشاه وقت اختصاص گرفتند و
#  کار دیگر می کند از آن روز در قرب و مصاحبت توری واقع شد در چهل و سیوم سال الهی
# یانی هرچند منصب چهارصدی داشت اما در مصاحبت و قرب پایه برتر افراخته بعزت و اعتب
# وابی و مطایبه گویی متصف بود و از پس مصاحبت پادشاه بهیچ یک سر فرو نمی آورد در ف
# ا با میرزا سلیمان والی بدخشان قرب و مصاحبت بهم رسانید و در زمره عمده های او من
# هی اختصاص یافته در کمتر زمانی بدولت مصاحبت و پایه قرب و منزلت برآمد و بخدمت صد
#  و نقش بندگی او با جنت مکانی بعنوان مصاحبت و ندیمی نشسته همواره در سیر و شکار
# ثقال خودرا برواحل بار کرده مستعد قطع مراحب شده بودند رسیده شتر و اسپ بسیار بدست
#  دلپسند آمد چون پیشنهاد همت والا قطع مراحب سفر بود لاجرم زیاده بر یک روز متوجه
# براه راست که چگونگی آن گذارش یافت طی مراحب و قطع منازل پیشنهاد عزیمت ساخته بیست
# ال فر و شان دوست نواز و دشمن گداز طی مراحب نموده وارد شهر عظیم آباد گردید و ظلا
# اندیشه تا کی برآید ز درگاه صاحب ندای مراحب جهان معانی سپهر وزارت محیط مکارم سحا
# حوب بوده بل ابد الآباد بطریق استصحاب مصاحب و مراقب ایشان باد اکنون کیفیت فتح تب
# ه حق آگاه و معالجه حکیم دا د که طبیب مصاحب شاه عباس کلان بود و بسبب بدسلوکی شاه
# که سید و فاضل و حکیم و منشی و شاعر و مصاحب و مشیر رازدار است اگرچه هنوز سپاهگری
# و شاکر خان بقدر ترقی کردند حرف المیم مصاحب بیگ ولد خواجه کلان بیگ که پدرش مولان
# ن ملحق گشت و چون خواجه درگذشت پسر او مصاحب بیگ بوسیله شایسته خدمتیهای نیاکان خو
#  بظهور می آمد چنانچه جنت آشیانی اورا مصاحب منافق می گفت پس از آنکه نوبت سلطنت ب
# ید بموقف عرض رساند و چون محب علی خان مصاحب شعور بود و کاردانی درست داشت عرش آشی
#  مردم تهمت آن را بر لطف بهایی خان که مصاحب و وکیل میرزا بود و بنابر آنکه با پدر
#  ساخت گویند آصفجاهی را از فوت این سه مصاحب بی نظیر حزنی و اندوهی طاری شد که اکث
# ا که در هنگام کامروایی و دولت افزایی مصاحب بی غنج بوده نگذارد که مآل کار ببدمست
# ایوس گشته از حیله اندوزی به کلا رفته مصاحب شد روز شهریور چهارم آذر ماه الهی که
# فه است بدارالسلطنه دهلی با سالخوردگی مصاحب باشعور بود و کاردانی خودرا از پرتو ع
# و عاطفت بهمزبانی خویش از آفت نکوهیده مصاحب باز دارند و از دوربینی و ژرف نگاهی ب
# ز مستی برنایی و شورش خودکامی و نبودن مصاحب دانا و ملازم خردپژوه خیراندیش روانه
# خان درویش مسکین بابا خان جم ن پور او مصاحب خان شاه علی بیگ ترکمان شهباز خان شاه
# ان فرمانروایی است تحم ل و بردباری را مصاحب دایمی خود باید گردانید که اساس دولت
# دل بدرد آمد که بزم افروز قدسی محفل و مصاحب آگاهدل را پیمانه حیات لبریز گشت نویی
# قه آمدند و چند روز متوالی از فدای آن مصاحب دانش آیین نویین اخلاص گزین مخاطب بلن
# قیقی و خدای مجازی است دل از همدمی آن مصاحب زیانکار برگرداند و از یک لحظه خرسندی
# صب هزاری رسیده سرفراز خان چغتا نبیره مصاحب بیگ همایونی است که احوالش نوک ریز خا
# و چون بهند معاودت کرد با فردوس مکانی مصاحب گشت و از جنت آشیانی تعظیم و احترام ب
# که هم برادر و هم فرزند و هم یار و هم مصاحب من است روزی که رسید حیات تازه یافته
# با جنت مکانی نرد و شطرنج می باختند و مصاحب و مقرب بودند اما بعد از فوت پدر آن ح
# کست ناز ارم رشک جن ه الماوی زهی ادیب مصاحب مآثر الامرا قلم حدیقه آراست از بهار
# قق حرف المیم یکصد و پنجاه و دو ترجمه مصاحب بیگ ملا میر محمد خان شیروانی میر شاه
# ی سپاه را میدهد بیشتر نویینان عظام بصاحبقران ثانی متوهم که مبادا بعد جلوس بتلاف
#  شصت و نه عیسوی خود را در بلخ ملقب بصاحبقران کرده ثمرقند را پای تخت را نمود در
# انید و لختی بحدود شرقیه بسر بوده از مصاحبان خان زمان بود در سال سیوم باندیشه نا
# ت محیی الدین خان را زنده نگاهداشت و مصاحبان و لشکریان اورا قاطبه از جان و امال
# جوانی و دولت شیفته شراب گشته از آفت مصاحبان خانه برانداز خوشامدپرداز می گساری ب
# باشد و کم تجربگی و عاقبت نااندیشی و مصاحبان ناجنس خیالات فاسد راه یافته بود بتخ
#  داشته اند اکثر اوقات آنجا نشسته با مصاحبان و مجلسیان خود صحبت می داشته اند من
#  بلند شده در خانه قاضی بایزید که از مصاحبان شاهزاده بود افتاد اسپ قاضی بفاصله س
# الدین محمد خوافی را که از ملازمان و مصاحبان و مخصوصان آصف خان بود با محمد تقی ب
# محمد کوسه لطیف طبع و شعرشناس بود از مصاحبان میر علی شیر و در ملازمت معز ز میزیس
# ج اردو پرداختند و اکثر کتب نفیسه که مصاحبان معنوی بودند و پیوسته با خود داشتندی
#  صلاح کار خود گم کرد و از ملازمان و مصاحبان او کسی که بهبود اورا منظور داشته حر
# تی از اوقات بحدود شرقیه بسر برده از مصاحبان مجلس خباثت علیقلی خان گشت و پسر خود
# مابین پادشاه و سادات فرخ سیر بتجویز مصاحبان هواخواه هرکرا می خواست بخدمتی از خد
# ولتخواهان دانشمند فرخ سیر خودپسند و مصاحبان ابله سبکسر او نشنیدند و آخر دیدند آ
# خواهد شد بحماقت خود و سپارش بعضی از مصاحبان که مثل صاحب خود بودند بر احوال آن ب
# مغتنمات شمردند و اکثر اوقات بر زبان مصاحبان مزاجدان این مصراع مذکور بود این کار
#  ملازمان ورشناس از عمله شاگردپیشه و مصاحبان و غیره همه را در بیاضی که اوراقش از
# امور نظامت بوده اند تعرضی نداشت اما مصاحبان و رفقای دیرینه او مثل میر مرتضی و ح
# ندان کسی در آنجا نماند مگر قلیلی از مصاحبان و تفنگچیان و در فرقه سواران فقط گوج
# ا پادشاه اورا از زمره مخلصان عاقل و مصاحبان دانادل می دانست نیز شقه نگاشته استش
# ح نماز واجبی را خوانده با معدودی از مصاحبان قهوه میل می فرمود و چون صبح طالع و
#  جنگ و صولت جنگ و سراج الدوله و بعض مصاحبان در آن مکان حاضر بوده صحبت اختلاط و
#  عنایت فرمود و رخصت کرد بعد چند روز مصاحبان سفیه نادانش باز برین صرافت آورده مر
# مود سراج الدوله که سفیه ترین مردم و مصاحبان از خود هم سفیه تر داشت و بر آداب حر
# وله چیزی می گفت ابلهان بخود مغرور و مصاحبان بی شعور حلقش چنان می فشردند که از گ
# عشق تا آنکه میان باغ رضوان آن هر دو مصاحبان جانی از درد و غم فراق رستند ای سیدی
# تشددی که در مذهب داشت جلد ثالث روضه الاحباب را که لختی افراط و تفریط در احوال س
# ام و مخترع نیستم همان وقت کتاب روضه الاحباب و دیگر کتب سیر از خزانه طلبیده بنقی
# ین و الف که حضرت قطب الاقطاب و مرشد الاحباب و زین الاصحاب مخزن سر لاهوت و مطلع
# ش چاک سید جمال الدین محد ث در رو ضه الاحباب و ملا علی قاری محد ث و مولوی عبد ال
#  بود تذکره قاری رحمت الله واضح تحفه الاحباب فی تذکره الاصحاب تالیف ه م تذکره ال
#  آبا و اجدادم را ترک کرده فایز تحفه الاحباب فی تذکره الاصحاب قاری رحمت الله ابن
# نگیز مسر ت آمیز اجل ه الاصحاب اغر ه الاحباب سالک مسالک مناثر و مناظم عارف مراتب
#  سوانح المسالک و عقاید النسا و تحفه الاحباب و برف و یخ است که مشهور بین ایادی ا
# یوسوف شرعه الاسلام اخلاق جلالی روضه الاحباب تفسیر مولانا یعقوب چرخی تحقیقات فضل
#  اب و القا السکینه و الحضور فی قلوب الاحباب وقتیکه ایشان بخراسان رسیدند قبولیت
# آگاهی بجناب ما حاصل گردید تخلص تحفه الاحباب فی تذکره الاصحاب قاری رحمت الله ابن
# ت کاشف انوار عبودیت قطب الاقطاب غوث الاحباب مقرب درگاه احدی م دب بارگاه بمریدی
# مت تذکره الشعرا حاجی عبدالعظیم تحفه الاحباب فی فی تذکره الاصحاب قاری رحمت الله
# ار اشعار شریفجان مخدوم صدر ضیا تحبه الاحباب فی تذکره الاصحاب تذکره الذاکرین ملا
# ذ ایام الفتی و احبه ما کان یزجیه مع الاحباب و بحکم این تجارب روشن می گردد که عا
#  بلبل ز بزم وصل او دورم الا یا ایها الاحباب اغیثونی اغیثونی که در ظلمت سرای تن
# علق به اسامی و القاب نه الص فا ص فه الاحباب وه م ش موس ب لاسحاب از آن که صفا صف
#  ن ن فس ه و ع ن ال ه وی و الا ن س ب الاحباب فکان ه بین المراتب واق ف ل م نال ح
# ود ه عند الآداب وح س ن الآداب ص ف ه الاحباب و هرکه را حق تعالی کرامتی دهد دلیل
# علق به اسامی و القاب نه الص فا ص فه الاحباب وه م ش موس ب لاسحاب از آن که صفا صف
#  ن ن فس ه و ع ن ال ه وی و الا ن س ب الاحباب فکان ه بین المراتب واق ف ل م نال ح
# ود ه عند الآداب وح س ن الآداب ص ف ه الاحباب و هرکه را حق تعالی کرامتی دهد دلیل
#  میرزا عبد الرحیم کوک گردید و ترانه مصاحبتش پرنوا برآمد در آن حالت بختش از گران
# ه استادان و پیران ما در آرزو دریافت مصاحبتش ترددها مینمایند بمشقت تمام این دولت
# مت در بنده گیش اختیار نمایم بآنمجرد مصاحبتش قناعت نموده متفیض از فیوض باطن و بر
# اهانش را از مشاعره اش بوی جامی و از مصاحبتش وجد بسطامی می آید در شرح تعر ف عطر
# فطرت از ستان لسان فایق در آزار و از مصاحبتش بیزار بود قاری ملا عبد الرازق متخلص
# پادشاهی رسید کوکه خان نامی که مادرش مصاحبه پادشاه بود بمهمانداری معین شد روز م
# اعیل کشمیری است در شاعره سلامت و در مصاحبه صلابت داشت کلامش خالی از رعونت و مر
#  و پایمال فیلان مست میگشتند و اموال بصاحبان میدادند در اندک فرصتی این فتنه و آش
# د بشناسد بگیرد و اکثر اسپان و اسباب بصاحبان مال رسید و این معنی باعث تازگی اقبا
# ن خود فرود آورده لوازم مهمانی ایشان بصاحبان منازل مفو ض ساخته بود همیشه حضرت جه
# ره روزگار می آمد بجای می آوردند اما بصاحبان اقبال م ی د ستیزه چه حاصل و بوالیان
#  غافل نیم لکن چه کنم که زرهای موعود بصاحبان انگلیش رسانیدن و دیگر امور ضروریه ر
# دانیده شد باید که عمال محالات خالصه بصاحبان مذکور رجوع نموده حسب الامر آنها بعم
#  ورود و وصول احدی از ستم رسیدگان تا بصاحبان اقتدار بنابر کشف استار خود نمی خواه
#  الحال فوجداری از دست هندیان برآمده بصاحبان انگلیش تعلق دارد این تعدی موقوف گشت
# ی خصم کار خودی لله الحمد که فوجداری بصاحبان انگلیشیه مقرر گشته این بلا هم از سر
# وت نیالایند الحمد لله که این کار هم بصاحبان تفویض یافته دست داروغه های هندی ازی
# هم بحباله نکاح فردوس آرامگاه درآمده بصاحبه محل مخاطب گشت بدینجهات او بعنایت خا
# د او سفارش برادران ملا محمد تت ی که مصاحبش بود کرد شاه بیگ خان شنیده بود که بر
# ر سنگه تمام نمود دولی سنگه کهتری که مصاحبش بود دویده خودرا باو رسانید اورا هم
# منونیها نوشتند زوجه محترمه اش مشهور بصاحبجی دختر نیک اختر علی مردان خان امیر ال
# ضبط و ربط و رتق و فتق آن ملک وابسته بصاحبجی است تا او هست احتمال تخلل ندارد خلد
# دین و دولت بودند و آنحضرت با ایشان مصاحبانه سلوک میکردند و بارها بزبان مقد س ا
# ات بی ادبانه نموده خواست که با شیخ مصاحبانه سلوک نماید و شیخ اورا بنظر زمیندار
# ار گردیدم و سخنهای یارانه و اختلاط مصاحبانه میسر آمد روز دیگر آشنای محض بود بن
# دید احوال دیگران عبرت گزین شود و نه مصاحبی خیراندیش دوربین که بسخن او اقتدا نم
# قلعه اتک رسانیدند و چون همچون بیربر مصاحبی غالب را بنفاق بباد داده آمده بودند
# تلو ن پادشاه و سبکی اوضاع ندیمان و مصاحبانش سرحقه راز گشودن و رهبری باین مصلحت
#  قزلباش را از دور می بینند و رفقا و مصاحبین او ورود کابلیان را سازش و فریب اعتم
# الدوله بجمیع قبایل و عشایر و رفقا و مصاحبین و ارباب طرب عنایت فرمود و خلاع فاخر
# ستخفاف با او نموده نمی گذارند که تا بصاحبش برسد و با منشی و دیوان سرکار صاحب خ
#  مالها را بلا ک ره آورده دادن حضرتم بصاحبش شماریدن حضرت امیر کبیر کس فرستادند
# ش مخالطت اینهارا بقدر ضرورت باید و مصاحبتشان بانداز حاجت شاید پیشتر اعتقادم این
# حاب القروح فی کثیر من نجاستها و وس ع لصاحب البواسیر فی بللها و جو ز الشارع ترک
#  ولایه التدریس بها و بین قضا بخارا و لصاحب الترجمه مدرسه بناها فی جنب مدرسه قلب
# ع مذکور بنمن مدعی بدهد متمرد است الخ لصاحب الحق ید الملازمه و لسان التقاضی بزاز
# احوال خیرمال عمده الامرا ظهیز الفقرا اخاحب الحنات جامع الخیرات مربعی اعلما معین
#  بیرون و غرور او نرفت ناز مهمان را زصاحبخانه می باید کشید نیست آسایش درین عالم
# سایه نخلی که ثمر داشته باشد آن کس که زصاحب نظران است چونرگس بایدبه ته پای نظردا
# یاخذه فی الله لومه لایم و اما الثانی فصاحب شرطه ینصف الضعفا من الاقویا معنی چنی
#  دلم با این رفیقان بی رفیق است ز بس ملاحبان کشتی غریق است نمی خواهی که زیر افتی
#  دلم با این رفیقان بی رفیق است ز بس ملاحبان کشتی غریق است نمی خواهی که زیر افتی
#  ملایت دموعی سوی کل حیا حالی کماکره الاحبه بعدهم واحب اعدایی من العدوا جمدت دم
#  لیلا الی الاقصی بذی الاسرا ض العیان کصاحب السرطان بل غیل البیان کصاحب الجوزا ا
# ض العیان کصاحب السرطان بل غیل البیان کصاحب الجوزا اصبحت داود ذالفضل حنظله ام بل
#  نعبد الاصنام راندم تاکنون دل به انی لااحب الافلین شد رهبرم در مقام عز عزلت در
# نی غافلست زانکه هر حجت که گوید آفلست لااحب الآفلین فرمود حق این سخن آسان نمای و
#  مراد و جفای زمانه ز بعد دیار و فراق صواحب ز تزویرهای جهان مزور ز بازیچه های سپ

# %% [markdown]
# ### Custom KWIC (beta)

# %%
five_grams = nltk.ngrams(doc_toks, 5)

# %%
five_grams = list(five_grams)
five_grams[5][2] == "پانصد"

# %%
search_toks = [x for x in five_grams if five_grams[x][2] is "پانصد"]
search_toks[:5]

# %% [markdown]
# ___
# ___

# %% [markdown]
# # Conditional Frequency

# %% [markdown]
# *Meta-Corpus*

# %%
# ConditionalFreqDist() takes a list of pairs.
# Generator variable uses itself up upon assignment, so need to recreate above

bigrams_cfd = nltk.ngrams(combined_toks, 2)

cfd = nltk.ConditionalFreqDist(bigrams_cfd)

# %% [markdown]
# ### Simple Conditional Frequency:

# %% [markdown]
# *Meta-Corpus*

# %%
search_term = ""

# %%
cfd[search_term].most_common(5)
# Out:
# [('را', 164), ('ای', 112), ('می', 91), ('وار', 80), ('به', 51)]

# %% [markdown]
# *Document Corpus*

# %%
bigrams_doc_fd = nltk.ngrams(doc_toks, 2)

cfd_doc = nltk.ConditionalFreqDist(bigrams_doc_fd)

# %%
search_term = "مقرر"
cfd_doc[search_term].most_common(5)
# Out:
# [('و', 27), ('بود', 6), ('شده', 5), ('گشته', 3), ('است', 3)]

# %% [markdown]
# ### Third term, if first two known:

# %% [markdown]
# *Document Corpus (Meta-Corpus simply too computationally costly)*

# %%
tri0 = nltk.ngrams(doc_toks, 3)
tri1 = [((a, b), c) for (a, b, c) in tri0]
cfd1 = nltk.ConditionalFreqDist(tri1)

# %%
first_term = "و"
second_term = "موفوره"

cfd1[(first_term, second_term)]
# Out:
# FreqDist({})

# %% [markdown]
# ### Reversed conditional frequency, i.e. if second word in sequence known but not first

# %% [markdown]
# *Meta-Corpus*

# %%
search_term = "راک"

# %%
bi0 = nltk.ngrams(combined_toks, 2)
bir = [(b, a) for (a, b) in bi0]
cfdr = nltk.ConditionalFreqDist(bir)

cfdr[search_term].most_common(15)
# Out:
# [('ی', 2), ('اثر', 2), ('مهر', 1), ('پ', 1), ('سجه', 1), ('بودند', 1)]
